# %% [markdown]
# <a href="https://colab.research.google.com/github/beuchi8888/Beuchi/blob/master/how_to_finetune_rf_detr_on_detection_dataset_pajaros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train RF-DETR Object Detection on a Custom Dataset
#
# ---
#
# [![hf space](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/SkalskiP/RF-DETR)
# [![colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-finetune-rf-detr-on-detection-dataset.ipynb)
# [![roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/rf-detr)
# [![code](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/rf-detr)
#
# RF-DETR is a real-time, transformer-based object detection model architecture developed by Roboflow and released under the Apache 2.0 license.
#
# ![rf-detr-coco-rf100-vl-8](https://media.roboflow.com/rf-detr/charts.png)
#
# RF-DETR is the first real-time model to exceed 60 AP on the [Microsoft COCO benchmark](https://cocodataset.org/#home) alongside competitive performance at base sizes. It also achieves state-of-the-art performance on [RF100-VL](https://github.com/roboflow/rf100-vl), an object detection benchmark that measures model domain adaptability to real world problems. RF-DETR is comparable speed to current real-time objection models.
#
# ![rf-detr-coco-results-2](https://media.roboflow.com/rf-detr/example_grid.png)
#
# RF-DETR is small enough to run on the edge, making it an ideal model for deployments that need both strong accuracy and real-time performance.

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Open your [`HuggingFace Settings`](https://huggingface.co/settings) page. Click `Access Tokens` then `New Token` to generate new token.
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store HuggingFace Access Token under the name `HF_TOKEN`.
#     - Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-defa0cab2495> in <cell line: 0>()
#       2 from google.colab import userdata
#       3
# ----> 4 os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
#       5 os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")
#
# /usr/local/lib/python3.11/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret HF_TOKEN does not exist.

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Fri Mar 21 07:18:03 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             47W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install dependencies

# %%
# !pip install -q rfdetr
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 15.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 92.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 51.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 63.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.9/354.9 kB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 77.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.5/765.5 kB 43.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.9 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done

# %% [markdown]
# ### Download example data

# %%
# !wget -q https://www.main-echo.de/storage/image/0/5/5/7/3647550_original1280_1zX9HV_2VVs82.jpg
# !wget -q https://france3-regions.francetvinfo.fr/image/GieI62TgGGFHAf6fvouAKHf0KhI/600x400/regions/2020/06/09/5edf996544936_bellpress-4653521.jpg

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %%
from rfdetr import RFDETRBase
from rfdetr.util.coco_classes import COCO_CLASSES
import supervision as sv
import numpy as np
from PIL import Image

image = Image.open("3647550_original1280_1zX9HV_2VVs82.jpg")

model = RFDETRBase()
detections = model.predict(image, threshold=0.5)

color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])
text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(color=color, thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    smart_position=True
)

labels = [
    f"{COCO_CLASSES[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = bbox_annotator.annotate(annotated_image, detections)
annotated_image = label_annotator.annotate(annotated_image, detections, labels)
annotated_image
# Out:
# rf-detr-base.pth: 100%|██████████| 355M/355M [00:16<00:00, 22.2MiB/s]
# UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/88.2M [00:00<?, ?B/s]
# Loading pretrain weights
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
# <PIL.Image.Image image mode=RGB size=1280x710>

# %%
from rfdetr import RFDETRBase
from rfdetr.util.coco_classes import COCO_CLASSES
import supervision as sv
import numpy as np
from PIL import Image

image = Image.open("5edf996544936_bellpress-4653521.jpg")

model = RFDETRBase()
detections = model.predict(image, threshold=0.5)

color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])
text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(color=color, thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    smart_position=True
)

labels = [
    f"{COCO_CLASSES[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = bbox_annotator.annotate(annotated_image, detections)
annotated_image = label_annotator.annotate(annotated_image, detections, labels)
annotated_image
# Out:
# Loading pretrain weights
# <PIL.Image.Image image mode=RGB size=600x400>

# %% [markdown]
# ## Download dataset from Roboflow Universe

# %%
from roboflow import download_dataset
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="x70jKlmPMid2F02BAO5e")
project = rf.workspace("sky-sd2zq").project("bird_only-pt0bm")
version = project.version(1)
dataset = version.download("coco")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.11/dist-packages (1.1.60)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.1.31)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.1.0)
# Requirement already satisfied: pillow-heif>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.22.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.57.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.1)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Bird_Only-1 to coco:: 100%|██████████| 346451/346451 [00:21<00:00, 16465.09it/s]
# Extracting Dataset Version Zip to Bird_Only-1 in coco:: 100%|██████████| 9899/9899 [00:01<00:00, 5087.65it/s]

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.
#
# ### Train with multiple GPUs
#
# You can fine-tune RF-DETR on multiple GPUs using PyTorch’s Distributed Data Parallel (DDP). Create a `main.py` script that initializes your model and calls `.train()` as usual than run it in terminal.
#
# ```bash
# python -m torch.distributed.launch \
#     --nproc_per_node=8 \
#     --use_env \
#     main.py
# ```
#
# Replace `8` in the `--nproc_per_node argument` with the number of GPUs you want to use. This approach creates one training process per GPU and splits the workload automatically. Note that your effective batch size is multiplied by the number of GPUs, so you may need to adjust your `batch_size` and `grad_accum_steps` to maintain the same overall batch size.

# %%
from rfdetr import RFDETRBase
import warnings
import os

warnings.filterwarnings("ignore", message="num_classes mismatch")

model = RFDETRBase()
history = []

def callback2(data):
     history.append(data)

model.callbacks["on_fit_epoch_end"].append(callback2)


model.train(dataset_dir=dataset.location, epochs=1, batch_size=4, grad_accum_steps=1, lr=1e-4)
# Out:
# Loading pretrain weights
# WARNING:rfdetr.detr:num_classes mismatch: model has 90 classes, but your dataset has 2 classes
# reinitializing your detection head with 2 classes.
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=2, grad_accum_steps=1, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=4, weight_decay=0.0001, epochs=1, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-base.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[2, 5, 8, 11], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='/content/Bird_Only-1', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=560, use_cls_token=False, multi_scale=True, expanded_scales=True, warmup_epochs=0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, tensorboard=True, wandb=False, project=None, run=None, class_names=['Bird'], distributed=False)
# number of params: 31854308
# [392, 448, 504, 560, 616, 672, 728, 784]
# loading annotations into memory...
# Done (t=0.40s)
# creating index...
# index created!
# [392, 448, 504, 560, 616, 672, 728, 784]
# loading annotations into memory...
# Done (t=0.78s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  1
# Total batch size:  4
# LENGTH OF DATA LOADER: 1666
# Epoch: [0]  [   0/1666]  eta: 2:00:04  lr: 0.000100  class_error: 33.57  loss: 10.5469 (10.5469)  loss_ce: 0.8335 (0.8335)  loss_bbox: 0.5168 (0.5168)  loss_giou: 1.2333 (1.2333)  loss_ce_0: 0.8098 (0.8098)  loss_bbox_0: 0.5681 (0.5681)  loss_giou_0: 1.2890 (1.2890)  loss_ce_1: 0.8132 (0.8132)  loss_bbox_1: 0.5082 (0.5082)  loss_giou_1: 1.2572 (1.2572)  loss_ce_enc: 0.7294 (0.7294)  loss_bbox_enc: 0.5826 (0.5826)  loss_giou_enc: 1.4057 (1.4057)  loss_ce_unscaled: 0.8335 (0.8335)  class_error_unscaled: 33.5664 (33.5664)  loss_bbox_unscaled: 0.1034 (0.1034)  loss_giou_unscaled: 0.6167 (0.6167)  cardinality_error_unscaled: 2595.5000 (2595.5000)  loss_ce_0_unscaled: 0.8098 (0.8098)  loss_bbox_0_unscaled: 0.1136 (0.1136)  loss_giou_0_unscaled: 0.6445 (0.6445)  cardinality_error_0_unscaled: 113.7500 (113.7500)  loss_ce_1_unscaled: 0.8132 (0.8132)  loss_bbox_1_unscaled: 0.1016 (0.1016)  loss_giou_1_unscaled: 0.6286 (0.6286)  cardinality_error_1_unscaled: 1979.5000 (1979.5000)  loss_ce_enc_unscaled: 0.7294 (0.7294)  loss_bbox_enc_unscaled: 0.1165 (0.1165)  loss_giou_enc_unscaled: 0.7028 (0.7028)  cardinality_error_enc_unscaled: 2781.7500 (2781.7500)  time: 4.3243  data: 0.6401  max mem: 6438
# Epoch: [0]  [  10/1666]  eta: 0:51:29  lr: 0.000100  class_error: 0.00  loss: 11.6397 (12.1573)  loss_ce: 0.8304 (0.8090)  loss_bbox: 0.8488 (0.8855)  loss_giou: 1.2333 (1.2879)  loss_ce_0: 0.8098 (0.8067)  loss_bbox_0: 0.8787 (0.9248)  loss_giou_0: 1.3167 (1.3241)  loss_ce_1: 0.8183 (0.8173)  loss_bbox_1: 0.8630 (0.8878)  loss_giou_1: 1.2572 (1.2970)  loss_ce_enc: 0.7391 (0.7685)  loss_bbox_enc: 0.8743 (0.9473)  loss_giou_enc: 1.3965 (1.4014)  loss_ce_unscaled: 0.8304 (0.8090)  class_error_unscaled: 9.1437 (9.8439)  loss_bbox_unscaled: 0.1698 (0.1771)  loss_giou_unscaled: 0.6167 (0.6440)  cardinality_error_unscaled: 186.2500 (692.0000)  loss_ce_0_unscaled: 0.8098 (0.8067)  loss_bbox_0_unscaled: 0.1757 (0.1850)  loss_giou_0_unscaled: 0.6583 (0.6620)  cardinality_error_0_unscaled: 14.7500 (37.3864)  loss_ce_1_unscaled: 0.8183 (0.8173)  loss_bbox_1_unscaled: 0.1726 (0.1776)  loss_giou_1_unscaled: 0.6286 (0.6485)  cardinality_error_1_unscaled: 1243.5000 (1136.1364)  loss_ce_enc_unscaled: 0.7391 (0.7685)  loss_bbox_enc_unscaled: 0.1749 (0.1895)  loss_giou_enc_unscaled: 0.6983 (0.7007)  cardinality_error_enc_unscaled: 2718.2500 (2634.6591)  time: 1.8655  data: 0.0739  max mem: 9111
# Epoch: [0]  [  20/1666]  eta: 0:47:53  lr: 0.000100  class_error: 0.00  loss: 10.1096 (10.8903)  loss_ce: 0.8099 (0.7994)  loss_bbox: 0.5184 (0.6729)  loss_giou: 1.1825 (1.1839)  loss_ce_0: 0.7933 (0.8107)  loss_bbox_0: 0.5665 (0.7059)  loss_giou_0: 1.2037 (1.2151)  loss_ce_1: 0.8169 (0.7961)  loss_bbox_1: 0.5467 (0.6769)  loss_giou_1: 1.2050 (1.1892)  loss_ce_enc: 0.7669 (0.8065)  loss_bbox_enc: 0.6206 (0.7410)  loss_giou_enc: 1.2482 (1.2925)  loss_ce_unscaled: 0.8099 (0.7994)  class_error_unscaled: 0.0000 (5.1563)  loss_bbox_unscaled: 0.1037 (0.1346)  loss_giou_unscaled: 0.5912 (0.5920)  cardinality_error_unscaled: 11.5000 (366.1190)  loss_ce_0_unscaled: 0.7933 (0.8107)  loss_bbox_0_unscaled: 0.1133 (0.1412)  loss_giou_0_unscaled: 0.6018 (0.6076)  cardinality_error_0_unscaled: 9.2500 (23.2143)  loss_ce_1_unscaled: 0.8169 (0.7961)  loss_bbox_1_unscaled: 0.1093 (0.1354)  loss_giou_1_unscaled: 0.6025 (0.5946)  cardinality_error_1_unscaled: 20.5000 (599.7857)  loss_ce_enc_unscaled: 0.7669 (0.8065)  loss_bbox_enc_unscaled: 0.1241 (0.1482)  loss_giou_enc_unscaled: 0.6241 (0.6463)  cardinality_error_enc_unscaled: 1893.0000 (2088.0595)  time: 1.6169  data: 0.0153  max mem: 9202
# Epoch: [0]  [  30/1666]  eta: 0:45:59  lr: 0.000100  class_error: -0.00  loss: 8.9264 (10.0931)  loss_ce: 0.7790 (0.7893)  loss_bbox: 0.3395 (0.5613)  loss_giou: 0.9194 (1.0788)  loss_ce_0: 0.8625 (0.8557)  loss_bbox_0: 0.3389 (0.5914)  loss_giou_0: 0.9605 (1.0999)  loss_ce_1: 0.7963 (0.7957)  loss_bbox_1: 0.3301 (0.5642)  loss_giou_1: 0.9555 (1.0838)  loss_ce_enc: 0.8967 (0.8528)  loss_bbox_enc: 0.4099 (0.6396)  loss_giou_enc: 0.9926 (1.1807)  loss_ce_unscaled: 0.7790 (0.7893)  class_error_unscaled: 0.0000 (3.4930)  loss_bbox_unscaled: 0.0679 (0.1123)  loss_giou_unscaled: 0.4597 (0.5394)  cardinality_error_unscaled: 3.2500 (249.3226)  loss_ce_0_unscaled: 0.8625 (0.8557)  loss_bbox_0_unscaled: 0.0678 (0.1183)  loss_giou_0_unscaled: 0.4802 (0.5499)  cardinality_error_0_unscaled: 3.2500 (17.0887)  loss_ce_1_unscaled: 0.7963 (0.7957)  loss_bbox_1_unscaled: 0.0660 (0.1128)  loss_giou_1_unscaled: 0.4778 (0.5419)  cardinality_error_1_unscaled: 10.5000 (412.8468)  loss_ce_enc_unscaled: 0.8967 (0.8528)  loss_bbox_enc_unscaled: 0.0820 (0.1279)  loss_giou_enc_unscaled: 0.4963 (0.5904)  cardinality_error_enc_unscaled: 1240.0000 (1799.1048)  time: 1.5885  data: 0.0142  max mem: 9202
# Epoch: [0]  [  40/1666]  eta: 0:46:25  lr: 0.000100  class_error: -0.00  loss: 7.9245 (9.6666)  loss_ce: 0.7569 (0.7840)  loss_bbox: 0.2869 (0.5091)  loss_giou: 0.8751 (1.0261)  loss_ce_0: 0.9262 (0.8683)  loss_bbox_0: 0.3341 (0.5290)  loss_giou_0: 0.8684 (1.0386)  loss_ce_1: 0.7884 (0.8004)  loss_bbox_1: 0.2963 (0.5069)  loss_giou_1: 0.8773 (1.0251)  loss_ce_enc: 0.9455 (0.8776)  loss_bbox_enc: 0.3820 (0.5809)  loss_giou_enc: 0.9350 (1.1206)  loss_ce_unscaled: 0.7569 (0.7840)  class_error_unscaled: 0.0000 (2.6410)  loss_bbox_unscaled: 0.0574 (0.1018)  loss_giou_unscaled: 0.4376 (0.5130)  cardinality_error_unscaled: 2.7500 (189.9573)  loss_ce_0_unscaled: 0.9262 (0.8683)  loss_bbox_0_unscaled: 0.0668 (0.1058)  loss_giou_0_unscaled: 0.4342 (0.5193)  cardinality_error_0_unscaled: 2.7500 (14.3902)  loss_ce_1_unscaled: 0.7884 (0.8004)  loss_bbox_1_unscaled: 0.0593 (0.1014)  loss_giou_1_unscaled: 0.4387 (0.5126)  cardinality_error_1_unscaled: 8.7500 (313.9390)  loss_ce_enc_unscaled: 0.9455 (0.8776)  loss_bbox_enc_unscaled: 0.0764 (0.1162)  loss_giou_enc_unscaled: 0.4675 (0.5603)  cardinality_error_enc_unscaled: 1071.7500 (1597.0061)  time: 1.6785  data: 0.0150  max mem: 9202
# Epoch: [0]  [  50/1666]  eta: 0:46:34  lr: 0.000100  class_error: 0.00  loss: 7.8409 (9.3756)  loss_ce: 0.7339 (0.7716)  loss_bbox: 0.2827 (0.4670)  loss_giou: 0.8332 (1.0089)  loss_ce_0: 0.8677 (0.8686)  loss_bbox_0: 0.2659 (0.4779)  loss_giou_0: 0.8231 (1.0137)  loss_ce_1: 0.7701 (0.7910)  loss_bbox_1: 0.2818 (0.4645)  loss_giou_1: 0.8425 (1.0076)  loss_ce_enc: 0.9331 (0.8830)  loss_bbox_enc: 0.3254 (0.5309)  loss_giou_enc: 0.8666 (1.0910)  loss_ce_unscaled: 0.7339 (0.7716)  class_error_unscaled: 0.0000 (2.1232)  loss_bbox_unscaled: 0.0565 (0.0934)  loss_giou_unscaled: 0.4166 (0.5044)  cardinality_error_unscaled: 4.7500 (154.2794)  loss_ce_0_unscaled: 0.8677 (0.8686)  loss_bbox_0_unscaled: 0.0532 (0.0956)  loss_giou_0_unscaled: 0.4115 (0.5068)  cardinality_error_0_unscaled: 4.7500 (13.1373)  loss_ce_1_unscaled: 0.7701 (0.7910)  loss_bbox_1_unscaled: 0.0564 (0.0929)  loss_giou_1_unscaled: 0.4212 (0.5038)  cardinality_error_1_unscaled: 5.5000 (253.8529)  loss_ce_enc_unscaled: 0.9331 (0.8830)  loss_bbox_enc_unscaled: 0.0651 (0.1062)  loss_giou_enc_unscaled: 0.4333 (0.5455)  cardinality_error_enc_unscaled: 890.5000 (1419.4167)  time: 1.7948  data: 0.0147  max mem: 9202
# Epoch: [0]  [  60/1666]  eta: 0:46:23  lr: 0.000100  class_error: 0.00  loss: 7.4431 (9.0487)  loss_ce: 0.7339 (0.7692)  loss_bbox: 0.2827 (0.4318)  loss_giou: 0.6980 (0.9667)  loss_ce_0: 0.8748 (0.8807)  loss_bbox_0: 0.2584 (0.4367)  loss_giou_0: 0.7195 (0.9645)  loss_ce_1: 0.7563 (0.7896)  loss_bbox_1: 0.2818 (0.4293)  loss_giou_1: 0.7082 (0.9659)  loss_ce_enc: 0.9592 (0.9033)  loss_bbox_enc: 0.2716 (0.4814)  loss_giou_enc: 0.7498 (1.0296)  loss_ce_unscaled: 0.7339 (0.7692)  class_error_unscaled: 0.0000 (1.7751)  loss_bbox_unscaled: 0.0565 (0.0864)  loss_giou_unscaled: 0.3490 (0.4833)  cardinality_error_unscaled: 7.5000 (130.0164)  loss_ce_0_unscaled: 0.8748 (0.8807)  loss_bbox_0_unscaled: 0.0517 (0.0873)  loss_giou_0_unscaled: 0.3597 (0.4822)  cardinality_error_0_unscaled: 7.5000 (12.0205)  loss_ce_1_unscaled: 0.7563 (0.7896)  loss_bbox_1_unscaled: 0.0564 (0.0859)  loss_giou_1_unscaled: 0.3541 (0.4829)  cardinality_error_1_unscaled: 7.5000 (213.9959)  loss_ce_enc_unscaled: 0.9592 (0.9033)  loss_bbox_enc_unscaled: 0.0543 (0.0963)  loss_giou_enc_unscaled: 0.3749 (0.5148)  cardinality_error_enc_unscaled: 452.5000 (1254.5820)  time: 1.7739  data: 0.0150  max mem: 9202
# Epoch: [0]  [  70/1666]  eta: 0:45:51  lr: 0.000100  class_error: -0.00  loss: 7.0723 (8.7915)  loss_ce: 0.7358 (0.7647)  loss_bbox: 0.2645 (0.4091)  loss_giou: 0.6889 (0.9301)  loss_ce_0: 0.9182 (0.8901)  loss_bbox_0: 0.1885 (0.4069)  loss_giou_0: 0.6313 (0.9215)  loss_ce_1: 0.7583 (0.7880)  loss_bbox_1: 0.2690 (0.4053)  loss_giou_1: 0.6817 (0.9294)  loss_ce_enc: 0.9841 (0.9163)  loss_bbox_enc: 0.2228 (0.4483)  loss_giou_enc: 0.6622 (0.9818)  loss_ce_unscaled: 0.7358 (0.7647)  class_error_unscaled: 0.0000 (1.5251)  loss_bbox_unscaled: 0.0529 (0.0818)  loss_giou_unscaled: 0.3445 (0.4650)  cardinality_error_unscaled: 5.2500 (112.4225)  loss_ce_0_unscaled: 0.9182 (0.8901)  loss_bbox_0_unscaled: 0.0377 (0.0814)  loss_giou_0_unscaled: 0.3157 (0.4608)  cardinality_error_0_unscaled: 5.2500 (11.0458)  loss_ce_1_unscaled: 0.7583 (0.7880)  loss_bbox_1_unscaled: 0.0538 (0.0811)  loss_giou_1_unscaled: 0.3408 (0.4647)  cardinality_error_1_unscaled: 10.7500 (186.0951)  loss_ce_enc_unscaled: 0.9841 (0.9163)  loss_bbox_enc_unscaled: 0.0446 (0.0897)  loss_giou_enc_unscaled: 0.3311 (0.4909)  cardinality_error_enc_unscaled: 287.2500 (1105.6620)  time: 1.7100  data: 0.0153  max mem: 9202
# Epoch: [0]  [  80/1666]  eta: 0:45:37  lr: 0.000100  class_error: 0.00  loss: 7.0723 (8.5848)  loss_ce: 0.7571 (0.7661)  loss_bbox: 0.2312 (0.3870)  loss_giou: 0.6774 (0.9014)  loss_ce_0: 0.9089 (0.8956)  loss_bbox_0: 0.1967 (0.3817)  loss_giou_0: 0.6313 (0.8915)  loss_ce_1: 0.7681 (0.7891)  loss_bbox_1: 0.2368 (0.3810)  loss_giou_1: 0.6800 (0.9010)  loss_ce_enc: 0.9658 (0.9214)  loss_bbox_enc: 0.1960 (0.4191)  loss_giou_enc: 0.6622 (0.9499)  loss_ce_unscaled: 0.7571 (0.7661)  class_error_unscaled: 0.0000 (1.3368)  loss_bbox_unscaled: 0.0462 (0.0774)  loss_giou_unscaled: 0.3387 (0.4507)  cardinality_error_unscaled: 4.7500 (99.5278)  loss_ce_0_unscaled: 0.9089 (0.8956)  loss_bbox_0_unscaled: 0.0393 (0.0763)  loss_giou_0_unscaled: 0.3157 (0.4458)  cardinality_error_0_unscaled: 4.7500 (10.6667)  loss_ce_1_unscaled: 0.7681 (0.7891)  loss_bbox_1_unscaled: 0.0474 (0.0762)  loss_giou_1_unscaled: 0.3400 (0.4505)  cardinality_error_1_unscaled: 12.5000 (164.4938)  loss_ce_enc_unscaled: 0.9658 (0.9214)  loss_bbox_enc_unscaled: 0.0392 (0.0838)  loss_giou_enc_unscaled: 0.3311 (0.4749)  cardinality_error_enc_unscaled: 68.5000 (972.5216)  time: 1.7059  data: 0.0143  max mem: 9202
# Epoch: [0]  [  90/1666]  eta: 0:45:08  lr: 0.000100  class_error: 0.00  loss: 7.0830 (8.4066)  loss_ce: 0.7504 (0.7585)  loss_bbox: 0.2082 (0.3746)  loss_giou: 0.6398 (0.8711)  loss_ce_0: 0.8964 (0.8975)  loss_bbox_0: 0.1970 (0.3666)  loss_giou_0: 0.6384 (0.8608)  loss_ce_1: 0.7537 (0.7835)  loss_bbox_1: 0.2159 (0.3679)  loss_giou_1: 0.6563 (0.8704)  loss_ce_enc: 0.9222 (0.9285)  loss_bbox_enc: 0.1991 (0.4071)  loss_giou_enc: 0.6776 (0.9202)  loss_ce_unscaled: 0.7504 (0.7585)  class_error_unscaled: 0.0000 (1.1899)  loss_bbox_unscaled: 0.0416 (0.0749)  loss_giou_unscaled: 0.3199 (0.4355)  cardinality_error_unscaled: 5.2500 (89.1236)  loss_ce_0_unscaled: 0.8964 (0.8975)  loss_bbox_0_unscaled: 0.0394 (0.0733)  loss_giou_0_unscaled: 0.3192 (0.4304)  cardinality_error_0_unscaled: 5.2500 (10.0275)  loss_ce_1_unscaled: 0.7537 (0.7835)  loss_bbox_1_unscaled: 0.0432 (0.0736)  loss_giou_1_unscaled: 0.3281 (0.4352)  cardinality_error_1_unscaled: 7.0000 (147.1126)  loss_ce_enc_unscaled: 0.9222 (0.9285)  loss_bbox_enc_unscaled: 0.0398 (0.0814)  loss_giou_enc_unscaled: 0.3388 (0.4601)  cardinality_error_enc_unscaled: 11.2500 (867.4451)  time: 1.6998  data: 0.0137  max mem: 9202
# Epoch: [0]  [ 100/1666]  eta: 0:44:42  lr: 0.000100  class_error: 0.00  loss: 6.9393 (8.2515)  loss_ce: 0.7262 (0.7551)  loss_bbox: 0.2000 (0.3579)  loss_giou: 0.6219 (0.8536)  loss_ce_0: 0.8734 (0.8969)  loss_bbox_0: 0.1896 (0.3498)  loss_giou_0: 0.6255 (0.8421)  loss_ce_1: 0.7451 (0.7803)  loss_bbox_1: 0.1975 (0.3515)  loss_giou_1: 0.6337 (0.8524)  loss_ce_enc: 0.9350 (0.9292)  loss_bbox_enc: 0.1909 (0.3862)  loss_giou_enc: 0.6634 (0.8967)  loss_ce_unscaled: 0.7262 (0.7551)  class_error_unscaled: 0.0000 (1.0721)  loss_bbox_unscaled: 0.0400 (0.0716)  loss_giou_unscaled: 0.3110 (0.4268)  cardinality_error_unscaled: 5.2500 (80.9381)  loss_ce_0_unscaled: 0.8734 (0.8969)  loss_bbox_0_unscaled: 0.0379 (0.0700)  loss_giou_0_unscaled: 0.3128 (0.4210)  cardinality_error_0_unscaled: 5.2500 (9.6733)  loss_ce_1_unscaled: 0.7451 (0.7803)  loss_bbox_1_unscaled: 0.0395 (0.0703)  loss_giou_1_unscaled: 0.3168 (0.4262)  cardinality_error_1_unscaled: 5.5000 (133.1683)  loss_ce_enc_unscaled: 0.9350 (0.9292)  loss_bbox_enc_unscaled: 0.0382 (0.0772)  loss_giou_enc_unscaled: 0.3317 (0.4484)  cardinality_error_enc_unscaled: 8.7500 (782.4851)  time: 1.6606  data: 0.0137  max mem: 9202
# Epoch: [0]  [ 110/1666]  eta: 0:43:59  lr: 0.000100  class_error: 0.00  loss: 6.6639 (8.1256)  loss_ce: 0.7239 (0.7518)  loss_bbox: 0.1702 (0.3466)  loss_giou: 0.7021 (0.8404)  loss_ce_0: 0.8627 (0.8941)  loss_bbox_0: 0.1664 (0.3348)  loss_giou_0: 0.6848 (0.8285)  loss_ce_1: 0.7431 (0.7771)  loss_bbox_1: 0.1684 (0.3397)  loss_giou_1: 0.7005 (0.8392)  loss_ce_enc: 0.9040 (0.9268)  loss_bbox_enc: 0.1710 (0.3682)  loss_giou_enc: 0.6786 (0.8784)  loss_ce_unscaled: 0.7239 (0.7518)  class_error_unscaled: 0.0000 (0.9755)  loss_bbox_unscaled: 0.0340 (0.0693)  loss_giou_unscaled: 0.3510 (0.4202)  cardinality_error_unscaled: 6.5000 (74.3829)  loss_ce_0_unscaled: 0.8627 (0.8941)  loss_bbox_0_unscaled: 0.0333 (0.0670)  loss_giou_0_unscaled: 0.3424 (0.4143)  cardinality_error_0_unscaled: 6.5000 (9.5383)  loss_ce_1_unscaled: 0.7431 (0.7771)  loss_bbox_1_unscaled: 0.0337 (0.0679)  loss_giou_1_unscaled: 0.3502 (0.4196)  cardinality_error_1_unscaled: 6.0000 (121.9279)  loss_ce_enc_unscaled: 0.9040 (0.9268)  loss_bbox_enc_unscaled: 0.0342 (0.0736)  loss_giou_enc_unscaled: 0.3393 (0.4392)  cardinality_error_enc_unscaled: 8.2500 (713.0023)  time: 1.5939  data: 0.0140  max mem: 9409
# Epoch: [0]  [ 120/1666]  eta: 0:43:55  lr: 0.000100  class_error: 0.00  loss: 6.5625 (8.0134)  loss_ce: 0.7112 (0.7448)  loss_bbox: 0.1763 (0.3365)  loss_giou: 0.7021 (0.8301)  loss_ce_0: 0.8397 (0.8870)  loss_bbox_0: 0.1664 (0.3250)  loss_giou_0: 0.6898 (0.8190)  loss_ce_1: 0.7380 (0.7701)  loss_bbox_1: 0.1852 (0.3303)  loss_giou_1: 0.7005 (0.8295)  loss_ce_enc: 0.8745 (0.9203)  loss_bbox_enc: 0.1690 (0.3555)  loss_giou_enc: 0.6786 (0.8653)  loss_ce_unscaled: 0.7112 (0.7448)  class_error_unscaled: 0.0000 (0.8949)  loss_bbox_unscaled: 0.0353 (0.0673)  loss_giou_unscaled: 0.3510 (0.4150)  cardinality_error_unscaled: 5.5000 (69.4690)  loss_ce_0_unscaled: 0.8397 (0.8870)  loss_bbox_0_unscaled: 0.0333 (0.0650)  loss_giou_0_unscaled: 0.3449 (0.4095)  cardinality_error_0_unscaled: 5.5000 (9.9835)  loss_ce_1_unscaled: 0.7380 (0.7701)  loss_bbox_1_unscaled: 0.0370 (0.0661)  loss_giou_1_unscaled: 0.3502 (0.4147)  cardinality_error_1_unscaled: 6.0000 (113.0868)  loss_ce_enc_unscaled: 0.8745 (0.9203)  loss_bbox_enc_unscaled: 0.0338 (0.0711)  loss_giou_enc_unscaled: 0.3393 (0.4327)  cardinality_error_enc_unscaled: 12.5000 (656.6302)  time: 1.6632  data: 0.0146  max mem: 12269
# Epoch: [0]  [ 130/1666]  eta: 0:43:20  lr: 0.000100  class_error: -0.00  loss: 6.3475 (7.8978)  loss_ce: 0.6717 (0.7415)  loss_bbox: 0.1776 (0.3265)  loss_giou: 0.6603 (0.8169)  loss_ce_0: 0.8312 (0.8816)  loss_bbox_0: 0.1751 (0.3149)  loss_giou_0: 0.6873 (0.8066)  loss_ce_1: 0.7151 (0.7659)  loss_bbox_1: 0.1852 (0.3206)  loss_giou_1: 0.6721 (0.8166)  loss_ce_enc: 0.8747 (0.9152)  loss_bbox_enc: 0.1595 (0.3426)  loss_giou_enc: 0.6580 (0.8490)  loss_ce_unscaled: 0.6717 (0.7415)  class_error_unscaled: 0.0000 (0.8266)  loss_bbox_unscaled: 0.0355 (0.0653)  loss_giou_unscaled: 0.3302 (0.4084)  cardinality_error_unscaled: 5.0000 (64.6298)  loss_ce_0_unscaled: 0.8312 (0.8816)  loss_bbox_0_unscaled: 0.0350 (0.0630)  loss_giou_0_unscaled: 0.3436 (0.4033)  cardinality_error_0_unscaled: 5.0000 (9.6889)  loss_ce_1_unscaled: 0.7151 (0.7659)  loss_bbox_1_unscaled: 0.0370 (0.0641)  loss_giou_1_unscaled: 0.3360 (0.4083)  cardinality_error_1_unscaled: 5.5000 (104.9370)  loss_ce_enc_unscaled: 0.8747 (0.9152)  loss_bbox_enc_unscaled: 0.0319 (0.0685)  loss_giou_enc_unscaled: 0.3290 (0.4245)  cardinality_error_enc_unscaled: 17.5000 (609.9866)  time: 1.6761  data: 0.0149  max mem: 12269
# Epoch: [0]  [ 140/1666]  eta: 0:42:56  lr: 0.000100  class_error: 0.00  loss: 6.2473 (7.7880)  loss_ce: 0.6744 (0.7364)  loss_bbox: 0.1641 (0.3173)  loss_giou: 0.6153 (0.8057)  loss_ce_0: 0.8177 (0.8753)  loss_bbox_0: 0.1584 (0.3054)  loss_giou_0: 0.6077 (0.7956)  loss_ce_1: 0.6808 (0.7590)  loss_bbox_1: 0.1629 (0.3117)  loss_giou_1: 0.6084 (0.8055)  loss_ce_enc: 0.8462 (0.9100)  loss_bbox_enc: 0.1523 (0.3310)  loss_giou_enc: 0.6163 (0.8353)  loss_ce_unscaled: 0.6744 (0.7364)  class_error_unscaled: 0.0000 (0.7680)  loss_bbox_unscaled: 0.0328 (0.0635)  loss_giou_unscaled: 0.3076 (0.4028)  cardinality_error_unscaled: 5.0000 (60.4752)  loss_ce_0_unscaled: 0.8177 (0.8753)  loss_bbox_0_unscaled: 0.0317 (0.0611)  loss_giou_0_unscaled: 0.3038 (0.3978)  cardinality_error_0_unscaled: 5.0000 (9.4309)  loss_ce_1_unscaled: 0.6808 (0.7590)  loss_bbox_1_unscaled: 0.0326 (0.0623)  loss_giou_1_unscaled: 0.3042 (0.4027)  cardinality_error_1_unscaled: 5.2500 (97.8723)  loss_ce_enc_unscaled: 0.8462 (0.9100)  loss_bbox_enc_unscaled: 0.0305 (0.0662)  loss_giou_enc_unscaled: 0.3081 (0.4176)  cardinality_error_enc_unscaled: 32.7500 (572.0479)  time: 1.5859  data: 0.0149  max mem: 12269
# Epoch: [0]  [ 150/1666]  eta: 0:42:37  lr: 0.000100  class_error: 0.00  loss: 5.9568 (7.6904)  loss_ce: 0.6762 (0.7375)  loss_bbox: 0.1217 (0.3058)  loss_giou: 0.6116 (0.7959)  loss_ce_0: 0.7635 (0.8704)  loss_bbox_0: 0.1257 (0.2945)  loss_giou_0: 0.5834 (0.7855)  loss_ce_1: 0.6811 (0.7595)  loss_bbox_1: 0.1225 (0.3005)  loss_giou_1: 0.6029 (0.7955)  loss_ce_enc: 0.7795 (0.9029)  loss_bbox_enc: 0.1364 (0.3188)  loss_giou_enc: 0.6163 (0.8235)  loss_ce_unscaled: 0.6762 (0.7375)  class_error_unscaled: 0.0000 (0.7171)  loss_bbox_unscaled: 0.0243 (0.0612)  loss_giou_unscaled: 0.3058 (0.3980)  cardinality_error_unscaled: 5.5000 (56.9752)  loss_ce_0_unscaled: 0.7635 (0.8704)  loss_bbox_0_unscaled: 0.0251 (0.0589)  loss_giou_0_unscaled: 0.2917 (0.3927)  cardinality_error_0_unscaled: 5.5000 (9.3146)  loss_ce_1_unscaled: 0.6811 (0.7595)  loss_bbox_1_unscaled: 0.0245 (0.0601)  loss_giou_1_unscaled: 0.3014 (0.3978)  cardinality_error_1_unscaled: 5.0000 (91.8825)  loss_ce_enc_unscaled: 0.7795 (0.9029)  loss_bbox_enc_unscaled: 0.0273 (0.0638)  loss_giou_enc_unscaled: 0.3081 (0.4117)  cardinality_error_enc_unscaled: 102.0000 (545.2483)  time: 1.6486  data: 0.0142  max mem: 12269
# Epoch: [0]  [ 160/1666]  eta: 0:42:20  lr: 0.000100  class_error: 0.00  loss: 6.1090 (7.6291)  loss_ce: 0.6785 (0.7370)  loss_bbox: 0.1023 (0.2966)  loss_giou: 0.6465 (0.7924)  loss_ce_0: 0.7700 (0.8653)  loss_bbox_0: 0.0998 (0.2862)  loss_giou_0: 0.6276 (0.7832)  loss_ce_1: 0.6887 (0.7585)  loss_bbox_1: 0.1030 (0.2917)  loss_giou_1: 0.6504 (0.7923)  loss_ce_enc: 0.7685 (0.8963)  loss_bbox_enc: 0.1234 (0.3097)  loss_giou_enc: 0.6779 (0.8199)  loss_ce_unscaled: 0.6785 (0.7370)  class_error_unscaled: 0.0000 (0.6726)  loss_bbox_unscaled: 0.0205 (0.0593)  loss_giou_unscaled: 0.3233 (0.3962)  cardinality_error_unscaled: 5.5000 (54.0404)  loss_ce_0_unscaled: 0.7700 (0.8653)  loss_bbox_0_unscaled: 0.0200 (0.0572)  loss_giou_0_unscaled: 0.3138 (0.3916)  cardinality_error_0_unscaled: 5.5000 (9.3401)  loss_ce_1_unscaled: 0.6887 (0.7585)  loss_bbox_1_unscaled: 0.0206 (0.0583)  loss_giou_1_unscaled: 0.3252 (0.3961)  cardinality_error_1_unscaled: 6.7500 (86.8199)  loss_ce_enc_unscaled: 0.7685 (0.8963)  loss_bbox_enc_unscaled: 0.0247 (0.0619)  loss_giou_enc_unscaled: 0.3390 (0.4100)  cardinality_error_enc_unscaled: 69.7500 (514.5994)  time: 1.6770  data: 0.0146  max mem: 12269
# Epoch: [0]  [ 170/1666]  eta: 0:42:07  lr: 0.000100  class_error: 0.00  loss: 6.3563 (7.5478)  loss_ce: 0.7283 (0.7364)  loss_bbox: 0.1288 (0.2909)  loss_giou: 0.6074 (0.7787)  loss_ce_0: 0.7934 (0.8624)  loss_bbox_0: 0.1253 (0.2808)  loss_giou_0: 0.6254 (0.7697)  loss_ce_1: 0.7367 (0.7575)  loss_bbox_1: 0.1277 (0.2862)  loss_giou_1: 0.6117 (0.7785)  loss_ce_enc: 0.8224 (0.8923)  loss_bbox_enc: 0.1647 (0.3054)  loss_giou_enc: 0.6588 (0.8089)  loss_ce_unscaled: 0.7283 (0.7364)  class_error_unscaled: 0.0000 (0.6332)  loss_bbox_unscaled: 0.0258 (0.0582)  loss_giou_unscaled: 0.3037 (0.3893)  cardinality_error_unscaled: 5.5000 (51.3187)  loss_ce_0_unscaled: 0.7934 (0.8624)  loss_bbox_0_unscaled: 0.0251 (0.0562)  loss_giou_0_unscaled: 0.3127 (0.3849)  cardinality_error_0_unscaled: 5.5000 (9.2325)  loss_ce_1_unscaled: 0.7367 (0.7575)  loss_bbox_1_unscaled: 0.0255 (0.0572)  loss_giou_1_unscaled: 0.3058 (0.3893)  cardinality_error_1_unscaled: 6.5000 (82.1681)  loss_ce_enc_unscaled: 0.8224 (0.8923)  loss_bbox_enc_unscaled: 0.0329 (0.0611)  loss_giou_enc_unscaled: 0.3294 (0.4044)  cardinality_error_enc_unscaled: 43.5000 (488.6740)  time: 1.7070  data: 0.0150  max mem: 12269
# Epoch: [0]  [ 180/1666]  eta: 0:41:35  lr: 0.000100  class_error: 0.00  loss: 6.1919 (7.4981)  loss_ce: 0.7253 (0.7369)  loss_bbox: 0.1303 (0.2849)  loss_giou: 0.5772 (0.7745)  loss_ce_0: 0.7934 (0.8601)  loss_bbox_0: 0.1253 (0.2744)  loss_giou_0: 0.5662 (0.7654)  loss_ce_1: 0.7382 (0.7570)  loss_bbox_1: 0.1314 (0.2807)  loss_giou_1: 0.5744 (0.7743)  loss_ce_enc: 0.8060 (0.8863)  loss_bbox_enc: 0.1647 (0.2988)  loss_giou_enc: 0.6639 (0.8047)  loss_ce_unscaled: 0.7253 (0.7369)  class_error_unscaled: 0.0000 (0.5982)  loss_bbox_unscaled: 0.0261 (0.0570)  loss_giou_unscaled: 0.2886 (0.3873)  cardinality_error_unscaled: 6.5000 (48.9088)  loss_ce_0_unscaled: 0.7934 (0.8601)  loss_bbox_0_unscaled: 0.0251 (0.0549)  loss_giou_0_unscaled: 0.2831 (0.3827)  cardinality_error_0_unscaled: 6.5000 (9.1478)  loss_ce_1_unscaled: 0.7382 (0.7570)  loss_bbox_1_unscaled: 0.0263 (0.0561)  loss_giou_1_unscaled: 0.2872 (0.3872)  cardinality_error_1_unscaled: 5.5000 (78.0483)  loss_ce_enc_unscaled: 0.8060 (0.8863)  loss_bbox_enc_unscaled: 0.0329 (0.0598)  loss_giou_enc_unscaled: 0.3320 (0.4023)  cardinality_error_enc_unscaled: 73.5000 (469.2638)  time: 1.6184  data: 0.0147  max mem: 12269
# Epoch: [0]  [ 190/1666]  eta: 0:41:24  lr: 0.000100  class_error: -0.00  loss: 6.6597 (7.4644)  loss_ce: 0.7142 (0.7350)  loss_bbox: 0.1507 (0.2807)  loss_giou: 0.6811 (0.7738)  loss_ce_0: 0.7739 (0.8569)  loss_bbox_0: 0.1380 (0.2704)  loss_giou_0: 0.6847 (0.7656)  loss_ce_1: 0.7327 (0.7548)  loss_bbox_1: 0.1559 (0.2768)  loss_giou_1: 0.6947 (0.7736)  loss_ce_enc: 0.7389 (0.8786)  loss_bbox_enc: 0.1523 (0.2939)  loss_giou_enc: 0.6909 (0.8044)  loss_ce_unscaled: 0.7142 (0.7350)  class_error_unscaled: 0.0000 (0.5669)  loss_bbox_unscaled: 0.0301 (0.0561)  loss_giou_unscaled: 0.3405 (0.3869)  cardinality_error_unscaled: 6.0000 (47.0484)  loss_ce_0_unscaled: 0.7739 (0.8569)  loss_bbox_0_unscaled: 0.0276 (0.0541)  loss_giou_0_unscaled: 0.3423 (0.3828)  cardinality_error_0_unscaled: 6.0000 (9.3691)  loss_ce_1_unscaled: 0.7327 (0.7548)  loss_bbox_1_unscaled: 0.0312 (0.0554)  loss_giou_1_unscaled: 0.3474 (0.3868)  cardinality_error_1_unscaled: 5.5000 (74.6492)  loss_ce_enc_unscaled: 0.7389 (0.8786)  loss_bbox_enc_unscaled: 0.0305 (0.0588)  loss_giou_enc_unscaled: 0.3455 (0.4022)  cardinality_error_enc_unscaled: 77.5000 (448.1741)  time: 1.6324  data: 0.0146  max mem: 12269
# Epoch: [0]  [ 200/1666]  eta: 0:41:15  lr: 0.000100  class_error: 0.00  loss: 6.2526 (7.4095)  loss_ce: 0.7142 (0.7345)  loss_bbox: 0.1450 (0.2753)  loss_giou: 0.6499 (0.7674)  loss_ce_0: 0.7739 (0.8543)  loss_bbox_0: 0.1380 (0.2650)  loss_giou_0: 0.6552 (0.7588)  loss_ce_1: 0.7190 (0.7540)  loss_bbox_1: 0.1467 (0.2714)  loss_giou_1: 0.6542 (0.7669)  loss_ce_enc: 0.7483 (0.8747)  loss_bbox_enc: 0.1523 (0.2888)  loss_giou_enc: 0.6525 (0.7984)  loss_ce_unscaled: 0.7142 (0.7345)  class_error_unscaled: 0.0000 (0.5387)  loss_bbox_unscaled: 0.0290 (0.0551)  loss_giou_unscaled: 0.3250 (0.3837)  cardinality_error_unscaled: 6.0000 (45.2612)  loss_ce_0_unscaled: 0.7739 (0.8543)  loss_bbox_0_unscaled: 0.0276 (0.0530)  loss_giou_0_unscaled: 0.3276 (0.3794)  cardinality_error_0_unscaled: 6.0000 (9.4577)  loss_ce_1_unscaled: 0.7190 (0.7540)  loss_bbox_1_unscaled: 0.0293 (0.0543)  loss_giou_1_unscaled: 0.3271 (0.3835)  cardinality_error_1_unscaled: 5.7500 (71.4863)  loss_ce_enc_unscaled: 0.7483 (0.8747)  loss_bbox_enc_unscaled: 0.0305 (0.0578)  loss_giou_enc_unscaled: 0.3262 (0.3992)  cardinality_error_enc_unscaled: 61.5000 (429.2326)  time: 1.7768  data: 0.0140  max mem: 12269
# Epoch: [0]  [ 210/1666]  eta: 0:40:46  lr: 0.000100  class_error: 0.00  loss: 6.0913 (7.3960)  loss_ce: 0.7380 (0.7415)  loss_bbox: 0.1310 (0.2707)  loss_giou: 0.5073 (0.7616)  loss_ce_0: 0.8130 (0.8637)  loss_bbox_0: 0.1313 (0.2607)  loss_giou_0: 0.5137 (0.7531)  loss_ce_1: 0.7552 (0.7613)  loss_bbox_1: 0.1285 (0.2669)  loss_giou_1: 0.4928 (0.7606)  loss_ce_enc: 0.7911 (0.8784)  loss_bbox_enc: 0.1559 (0.2850)  loss_giou_enc: 0.5584 (0.7925)  loss_ce_unscaled: 0.7380 (0.7415)  class_error_unscaled: 0.0000 (0.5132)  loss_bbox_unscaled: 0.0262 (0.0541)  loss_giou_unscaled: 0.2537 (0.3808)  cardinality_error_unscaled: 4.7500 (43.4491)  loss_ce_0_unscaled: 0.8130 (0.8637)  loss_bbox_0_unscaled: 0.0263 (0.0521)  loss_giou_0_unscaled: 0.2568 (0.3765)  cardinality_error_0_unscaled: 4.7500 (9.3424)  loss_ce_1_unscaled: 0.7552 (0.7613)  loss_bbox_1_unscaled: 0.0257 (0.0534)  loss_giou_1_unscaled: 0.2464 (0.3803)  cardinality_error_1_unscaled: 4.5000 (68.4230)  loss_ce_enc_unscaled: 0.7911 (0.8784)  loss_bbox_enc_unscaled: 0.0312 (0.0570)  loss_giou_enc_unscaled: 0.2792 (0.3962)  cardinality_error_enc_unscaled: 55.2500 (412.6718)  time: 1.6498  data: 0.0138  max mem: 12269
# Epoch: [0]  [ 220/1666]  eta: 0:40:31  lr: 0.000100  class_error: 0.00  loss: 6.5665 (7.3562)  loss_ce: 0.7421 (0.7408)  loss_bbox: 0.1377 (0.2656)  loss_giou: 0.6565 (0.7593)  loss_ce_0: 0.8197 (0.8605)  loss_bbox_0: 0.1359 (0.2560)  loss_giou_0: 0.6558 (0.7512)  loss_ce_1: 0.7552 (0.7599)  loss_bbox_1: 0.1437 (0.2620)  loss_giou_1: 0.6522 (0.7583)  loss_ce_enc: 0.7548 (0.8724)  loss_bbox_enc: 0.1728 (0.2800)  loss_giou_enc: 0.6945 (0.7902)  loss_ce_unscaled: 0.7421 (0.7408)  class_error_unscaled: 0.0000 (0.4900)  loss_bbox_unscaled: 0.0275 (0.0531)  loss_giou_unscaled: 0.3282 (0.3796)  cardinality_error_unscaled: 5.2500 (41.9197)  loss_ce_0_unscaled: 0.8197 (0.8605)  loss_bbox_0_unscaled: 0.0272 (0.0512)  loss_giou_0_unscaled: 0.3279 (0.3756)  cardinality_error_0_unscaled: 5.2500 (9.3586)  loss_ce_1_unscaled: 0.7552 (0.7599)  loss_bbox_1_unscaled: 0.0287 (0.0524)  loss_giou_1_unscaled: 0.3261 (0.3791)  cardinality_error_1_unscaled: 5.2500 (65.7523)  loss_ce_enc_unscaled: 0.7548 (0.8724)  loss_bbox_enc_unscaled: 0.0346 (0.0560)  loss_giou_enc_unscaled: 0.3473 (0.3951)  cardinality_error_enc_unscaled: 54.0000 (396.7195)  time: 1.6110  data: 0.0147  max mem: 12269
# Epoch: [0]  [ 230/1666]  eta: 0:40:13  lr: 0.000100  class_error: 0.00  loss: 6.6330 (7.3372)  loss_ce: 0.7246 (0.7444)  loss_bbox: 0.1486 (0.2639)  loss_giou: 0.6565 (0.7547)  loss_ce_0: 0.7976 (0.8614)  loss_bbox_0: 0.1462 (0.2540)  loss_giou_0: 0.6431 (0.7464)  loss_ce_1: 0.7411 (0.7625)  loss_bbox_1: 0.1465 (0.2602)  loss_giou_1: 0.6522 (0.7535)  loss_ce_enc: 0.7490 (0.8721)  loss_bbox_enc: 0.1754 (0.2782)  loss_giou_enc: 0.6945 (0.7860)  loss_ce_unscaled: 0.7246 (0.7444)  class_error_unscaled: 0.0000 (0.4688)  loss_bbox_unscaled: 0.0297 (0.0528)  loss_giou_unscaled: 0.3282 (0.3774)  cardinality_error_unscaled: 6.5000 (40.3431)  loss_ce_0_unscaled: 0.7976 (0.8614)  loss_bbox_0_unscaled: 0.0292 (0.0508)  loss_giou_0_unscaled: 0.3215 (0.3732)  cardinality_error_0_unscaled: 6.5000 (9.1937)  loss_ce_1_unscaled: 0.7411 (0.7625)  loss_bbox_1_unscaled: 0.0293 (0.0520)  loss_giou_1_unscaled: 0.3261 (0.3767)  cardinality_error_1_unscaled: 6.0000 (63.1353)  loss_ce_enc_unscaled: 0.7490 (0.8721)  loss_bbox_enc_unscaled: 0.0351 (0.0556)  loss_giou_enc_unscaled: 0.3473 (0.3930)  cardinality_error_enc_unscaled: 38.0000 (380.7327)  time: 1.6829  data: 0.0149  max mem: 12269
# Epoch: [0]  [ 240/1666]  eta: 0:39:51  lr: 0.000100  class_error: 0.00  loss: 6.3687 (7.2898)  loss_ce: 0.7246 (0.7436)  loss_bbox: 0.1596 (0.2602)  loss_giou: 0.5856 (0.7478)  loss_ce_0: 0.7991 (0.8595)  loss_bbox_0: 0.1476 (0.2507)  loss_giou_0: 0.5918 (0.7397)  loss_ce_1: 0.7411 (0.7616)  loss_bbox_1: 0.1557 (0.2570)  loss_giou_1: 0.5842 (0.7467)  loss_ce_enc: 0.8087 (0.8687)  loss_bbox_enc: 0.1681 (0.2747)  loss_giou_enc: 0.6235 (0.7798)  loss_ce_unscaled: 0.7246 (0.7436)  class_error_unscaled: 0.0000 (0.4493)  loss_bbox_unscaled: 0.0319 (0.0520)  loss_giou_unscaled: 0.2928 (0.3739)  cardinality_error_unscaled: 5.0000 (38.8973)  loss_ce_0_unscaled: 0.7991 (0.8595)  loss_bbox_0_unscaled: 0.0295 (0.0501)  loss_giou_0_unscaled: 0.2959 (0.3698)  cardinality_error_0_unscaled: 5.2500 (9.0353)  loss_ce_1_unscaled: 0.7411 (0.7616)  loss_bbox_1_unscaled: 0.0311 (0.0514)  loss_giou_1_unscaled: 0.2921 (0.3733)  cardinality_error_1_unscaled: 5.2500 (60.9170)  loss_ce_enc_unscaled: 0.8087 (0.8687)  loss_bbox_enc_unscaled: 0.0336 (0.0549)  loss_giou_enc_unscaled: 0.3117 (0.3899)  cardinality_error_enc_unscaled: 15.7500 (366.9263)  time: 1.6243  data: 0.0146  max mem: 12269
# Epoch: [0]  [ 250/1666]  eta: 0:39:19  lr: 0.000100  class_error: 0.00  loss: 6.3687 (7.2719)  loss_ce: 0.7034 (0.7422)  loss_bbox: 0.1596 (0.2598)  loss_giou: 0.6309 (0.7463)  loss_ce_0: 0.7856 (0.8565)  loss_bbox_0: 0.1550 (0.2502)  loss_giou_0: 0.6249 (0.7378)  loss_ce_1: 0.7187 (0.7602)  loss_bbox_1: 0.1589 (0.2566)  loss_giou_1: 0.6428 (0.7450)  loss_ce_enc: 0.7545 (0.8652)  loss_bbox_enc: 0.1812 (0.2738)  loss_giou_enc: 0.6585 (0.7783)  loss_ce_unscaled: 0.7034 (0.7422)  class_error_unscaled: 0.0000 (0.4314)  loss_bbox_unscaled: 0.0319 (0.0520)  loss_giou_unscaled: 0.3154 (0.3731)  cardinality_error_unscaled: 5.0000 (37.5946)  loss_ce_0_unscaled: 0.7856 (0.8565)  loss_bbox_0_unscaled: 0.0310 (0.0500)  loss_giou_0_unscaled: 0.3125 (0.3689)  cardinality_error_0_unscaled: 5.0000 (8.9223)  loss_ce_1_unscaled: 0.7187 (0.7602)  loss_bbox_1_unscaled: 0.0318 (0.0513)  loss_giou_1_unscaled: 0.3214 (0.3725)  cardinality_error_1_unscaled: 6.2500 (58.7739)  loss_ce_enc_unscaled: 0.7545 (0.8652)  loss_bbox_enc_unscaled: 0.0362 (0.0548)  loss_giou_enc_unscaled: 0.3293 (0.3892)  cardinality_error_enc_unscaled: 41.0000 (354.8695)  time: 1.5055  data: 0.0150  max mem: 12269
# Epoch: [0]  [ 260/1666]  eta: 0:39:10  lr: 0.000100  class_error: -0.00  loss: 6.2684 (7.2217)  loss_ce: 0.6838 (0.7390)  loss_bbox: 0.1758 (0.2566)  loss_giou: 0.6214 (0.7409)  loss_ce_0: 0.7375 (0.8516)  loss_bbox_0: 0.1822 (0.2474)  loss_giou_0: 0.6249 (0.7327)  loss_ce_1: 0.6960 (0.7567)  loss_bbox_1: 0.1776 (0.2536)  loss_giou_1: 0.6384 (0.7396)  loss_ce_enc: 0.7274 (0.8593)  loss_bbox_enc: 0.1975 (0.2708)  loss_giou_enc: 0.6587 (0.7736)  loss_ce_unscaled: 0.6838 (0.7390)  class_error_unscaled: 0.0000 (0.4149)  loss_bbox_unscaled: 0.0352 (0.0513)  loss_giou_unscaled: 0.3107 (0.3704)  cardinality_error_unscaled: 4.7500 (36.4521)  loss_ce_0_unscaled: 0.7375 (0.8516)  loss_bbox_0_unscaled: 0.0364 (0.0495)  loss_giou_0_unscaled: 0.3125 (0.3663)  cardinality_error_0_unscaled: 4.7500 (8.8831)  loss_ce_1_unscaled: 0.6960 (0.7567)  loss_bbox_1_unscaled: 0.0355 (0.0507)  loss_giou_1_unscaled: 0.3192 (0.3698)  cardinality_error_1_unscaled: 5.0000 (56.8333)  loss_ce_enc_unscaled: 0.7274 (0.8593)  loss_bbox_enc_unscaled: 0.0395 (0.0542)  loss_giou_enc_unscaled: 0.3294 (0.3868)  cardinality_error_enc_unscaled: 20.0000 (342.3276)  time: 1.6120  data: 0.0149  max mem: 12269
# Epoch: [0]  [ 270/1666]  eta: 0:38:59  lr: 0.000100  class_error: 0.00  loss: 6.1661 (7.1865)  loss_ce: 0.6633 (0.7361)  loss_bbox: 0.1456 (0.2537)  loss_giou: 0.6147 (0.7382)  loss_ce_0: 0.7234 (0.8467)  loss_bbox_0: 0.1412 (0.2455)  loss_giou_0: 0.6182 (0.7306)  loss_ce_1: 0.6580 (0.7533)  loss_bbox_1: 0.1429 (0.2509)  loss_giou_1: 0.6148 (0.7371)  loss_ce_enc: 0.7035 (0.8539)  loss_bbox_enc: 0.1599 (0.2688)  loss_giou_enc: 0.6730 (0.7717)  loss_ce_unscaled: 0.6633 (0.7361)  class_error_unscaled: 0.0000 (0.3996)  loss_bbox_unscaled: 0.0291 (0.0507)  loss_giou_unscaled: 0.3073 (0.3691)  cardinality_error_unscaled: 5.7500 (35.4096)  loss_ce_0_unscaled: 0.7234 (0.8467)  loss_bbox_0_unscaled: 0.0282 (0.0491)  loss_giou_0_unscaled: 0.3091 (0.3653)  cardinality_error_0_unscaled: 5.7500 (8.8589)  loss_ce_1_unscaled: 0.6580 (0.7533)  loss_bbox_1_unscaled: 0.0286 (0.0502)  loss_giou_1_unscaled: 0.3074 (0.3685)  cardinality_error_1_unscaled: 6.0000 (55.0784)  loss_ce_enc_unscaled: 0.7035 (0.8539)  loss_bbox_enc_unscaled: 0.0320 (0.0538)  loss_giou_enc_unscaled: 0.3365 (0.3859)  cardinality_error_enc_unscaled: 18.2500 (330.9133)  time: 1.7889  data: 0.0146  max mem: 12269
# Epoch: [0]  [ 280/1666]  eta: 0:38:45  lr: 0.000100  class_error: 0.00  loss: 6.1860 (7.1617)  loss_ce: 0.6633 (0.7346)  loss_bbox: 0.1442 (0.2513)  loss_giou: 0.6537 (0.7369)  loss_ce_0: 0.7145 (0.8431)  loss_bbox_0: 0.1412 (0.2431)  loss_giou_0: 0.6583 (0.7297)  loss_ce_1: 0.6580 (0.7514)  loss_bbox_1: 0.1425 (0.2485)  loss_giou_1: 0.6437 (0.7358)  loss_ce_enc: 0.7096 (0.8501)  loss_bbox_enc: 0.1568 (0.2659)  loss_giou_enc: 0.7244 (0.7712)  loss_ce_unscaled: 0.6633 (0.7346)  class_error_unscaled: 0.0000 (0.3853)  loss_bbox_unscaled: 0.0288 (0.0503)  loss_giou_unscaled: 0.3268 (0.3685)  cardinality_error_unscaled: 7.0000 (34.4511)  loss_ce_0_unscaled: 0.7145 (0.8431)  loss_bbox_0_unscaled: 0.0282 (0.0486)  loss_giou_0_unscaled: 0.3292 (0.3648)  cardinality_error_0_unscaled: 7.0000 (8.8443)  loss_ce_1_unscaled: 0.6580 (0.7514)  loss_bbox_1_unscaled: 0.0285 (0.0497)  loss_giou_1_unscaled: 0.3219 (0.3679)  cardinality_error_1_unscaled: 6.7500 (53.4146)  loss_ce_enc_unscaled: 0.7096 (0.8501)  loss_bbox_enc_unscaled: 0.0314 (0.0532)  loss_giou_enc_unscaled: 0.3622 (0.3856)  cardinality_error_enc_unscaled: 13.7500 (320.2046)  time: 1.7510  data: 0.0144  max mem: 12269
# Epoch: [0]  [ 290/1666]  eta: 0:38:24  lr: 0.000100  class_error: 0.00  loss: 6.1860 (7.1228)  loss_ce: 0.6704 (0.7323)  loss_bbox: 0.1443 (0.2495)  loss_giou: 0.6342 (0.7319)  loss_ce_0: 0.7155 (0.8391)  loss_bbox_0: 0.1488 (0.2415)  loss_giou_0: 0.6485 (0.7250)  loss_ce_1: 0.6775 (0.7487)  loss_bbox_1: 0.1531 (0.2467)  loss_giou_1: 0.6331 (0.7307)  loss_ce_enc: 0.7152 (0.8462)  loss_bbox_enc: 0.1745 (0.2640)  loss_giou_enc: 0.7154 (0.7671)  loss_ce_unscaled: 0.6704 (0.7323)  class_error_unscaled: 0.0000 (0.3721)  loss_bbox_unscaled: 0.0289 (0.0499)  loss_giou_unscaled: 0.3171 (0.3659)  cardinality_error_unscaled: 5.7500 (33.4794)  loss_ce_0_unscaled: 0.7155 (0.8391)  loss_bbox_0_unscaled: 0.0298 (0.0483)  loss_giou_0_unscaled: 0.3242 (0.3625)  cardinality_error_0_unscaled: 5.7500 (8.7552)  loss_ce_1_unscaled: 0.6775 (0.7487)  loss_bbox_1_unscaled: 0.0306 (0.0493)  loss_giou_1_unscaled: 0.3166 (0.3654)  cardinality_error_1_unscaled: 5.7500 (51.7895)  loss_ce_enc_unscaled: 0.7152 (0.8462)  loss_bbox_enc_unscaled: 0.0349 (0.0528)  loss_giou_enc_unscaled: 0.3577 (0.3836)  cardinality_error_enc_unscaled: 19.7500 (311.0077)  time: 1.6631  data: 0.0144  max mem: 12269
# Epoch: [0]  [ 300/1666]  eta: 0:38:07  lr: 0.000100  class_error: 0.00  loss: 6.1962 (7.1075)  loss_ce: 0.6723 (0.7314)  loss_bbox: 0.1605 (0.2488)  loss_giou: 0.6342 (0.7310)  loss_ce_0: 0.7681 (0.8370)  loss_bbox_0: 0.1621 (0.2403)  loss_giou_0: 0.6485 (0.7240)  loss_ce_1: 0.6836 (0.7478)  loss_bbox_1: 0.1635 (0.2458)  loss_giou_1: 0.6331 (0.7297)  loss_ce_enc: 0.7359 (0.8430)  loss_bbox_enc: 0.1757 (0.2626)  loss_giou_enc: 0.6881 (0.7661)  loss_ce_unscaled: 0.6723 (0.7314)  class_error_unscaled: 0.0000 (0.3597)  loss_bbox_unscaled: 0.0321 (0.0498)  loss_giou_unscaled: 0.3171 (0.3655)  cardinality_error_unscaled: 4.5000 (32.6453)  loss_ce_0_unscaled: 0.7681 (0.8370)  loss_bbox_0_unscaled: 0.0324 (0.0481)  loss_giou_0_unscaled: 0.3242 (0.3620)  cardinality_error_0_unscaled: 4.5000 (8.7400)  loss_ce_1_unscaled: 0.6836 (0.7478)  loss_bbox_1_unscaled: 0.0327 (0.0492)  loss_giou_1_unscaled: 0.3166 (0.3648)  cardinality_error_1_unscaled: 6.0000 (50.4593)  loss_ce_enc_unscaled: 0.7359 (0.8430)  loss_bbox_enc_unscaled: 0.0351 (0.0525)  loss_giou_enc_unscaled: 0.3440 (0.3831)  cardinality_error_enc_unscaled: 48.7500 (302.7425)  time: 1.6311  data: 0.0148  max mem: 12269
# Epoch: [0]  [ 310/1666]  eta: 0:37:50  lr: 0.000100  class_error: 0.00  loss: 6.3033 (7.0776)  loss_ce: 0.6928 (0.7297)  loss_bbox: 0.1440 (0.2458)  loss_giou: 0.7082 (0.7296)  loss_ce_0: 0.7548 (0.8336)  loss_bbox_0: 0.1506 (0.2375)  loss_giou_0: 0.7209 (0.7223)  loss_ce_1: 0.6916 (0.7456)  loss_bbox_1: 0.1430 (0.2429)  loss_giou_1: 0.7288 (0.7282)  loss_ce_enc: 0.7359 (0.8389)  loss_bbox_enc: 0.1692 (0.2595)  loss_giou_enc: 0.7553 (0.7640)  loss_ce_unscaled: 0.6928 (0.7297)  class_error_unscaled: 0.0000 (0.3482)  loss_bbox_unscaled: 0.0288 (0.0492)  loss_giou_unscaled: 0.3541 (0.3648)  cardinality_error_unscaled: 7.5000 (31.8891)  loss_ce_0_unscaled: 0.7548 (0.8336)  loss_bbox_0_unscaled: 0.0301 (0.0475)  loss_giou_0_unscaled: 0.3604 (0.3612)  cardinality_error_0_unscaled: 7.5000 (8.7524)  loss_ce_1_unscaled: 0.6916 (0.7456)  loss_bbox_1_unscaled: 0.0286 (0.0486)  loss_giou_1_unscaled: 0.3644 (0.3641)  cardinality_error_1_unscaled: 7.5000 (49.1286)  loss_ce_enc_unscaled: 0.7359 (0.8389)  loss_bbox_enc_unscaled: 0.0338 (0.0519)  loss_giou_enc_unscaled: 0.3776 (0.3820)  cardinality_error_enc_unscaled: 13.0000 (293.5868)  time: 1.6724  data: 0.0147  max mem: 12269
# Epoch: [0]  [ 320/1666]  eta: 0:37:31  lr: 0.000100  class_error: 0.00  loss: 6.0884 (7.0478)  loss_ce: 0.6850 (0.7293)  loss_bbox: 0.1270 (0.2420)  loss_giou: 0.6531 (0.7274)  loss_ce_0: 0.7364 (0.8318)  loss_bbox_0: 0.1248 (0.2338)  loss_giou_0: 0.6134 (0.7200)  loss_ce_1: 0.6916 (0.7449)  loss_bbox_1: 0.1253 (0.2391)  loss_giou_1: 0.6477 (0.7260)  loss_ce_enc: 0.7242 (0.8364)  loss_bbox_enc: 0.1551 (0.2555)  loss_giou_enc: 0.6699 (0.7616)  loss_ce_unscaled: 0.6850 (0.7293)  class_error_unscaled: 0.0000 (0.3373)  loss_bbox_unscaled: 0.0254 (0.0484)  loss_giou_unscaled: 0.3265 (0.3637)  cardinality_error_unscaled: 6.7500 (31.1900)  loss_ce_0_unscaled: 0.7364 (0.8318)  loss_bbox_0_unscaled: 0.0250 (0.0468)  loss_giou_0_unscaled: 0.3067 (0.3600)  cardinality_error_0_unscaled: 7.0000 (8.7749)  loss_ce_1_unscaled: 0.6916 (0.7449)  loss_bbox_1_unscaled: 0.0251 (0.0478)  loss_giou_1_unscaled: 0.3239 (0.3630)  cardinality_error_1_unscaled: 7.0000 (47.8933)  loss_ce_enc_unscaled: 0.7242 (0.8364)  loss_bbox_enc_unscaled: 0.0310 (0.0511)  loss_giou_enc_unscaled: 0.3349 (0.3808)  cardinality_error_enc_unscaled: 8.5000 (285.0070)  time: 1.6456  data: 0.0142  max mem: 12269
# Epoch: [0]  [ 330/1666]  eta: 0:37:16  lr: 0.000100  class_error: 0.00  loss: 6.0884 (7.0282)  loss_ce: 0.6747 (0.7281)  loss_bbox: 0.1286 (0.2403)  loss_giou: 0.6381 (0.7265)  loss_ce_0: 0.7291 (0.8293)  loss_bbox_0: 0.1248 (0.2321)  loss_giou_0: 0.6134 (0.7189)  loss_ce_1: 0.6829 (0.7433)  loss_bbox_1: 0.1290 (0.2375)  loss_giou_1: 0.6294 (0.7253)  loss_ce_enc: 0.7293 (0.8336)  loss_bbox_enc: 0.1309 (0.2534)  loss_giou_enc: 0.6699 (0.7601)  loss_ce_unscaled: 0.6747 (0.7281)  class_error_unscaled: 0.0000 (0.3271)  loss_bbox_unscaled: 0.0257 (0.0481)  loss_giou_unscaled: 0.3190 (0.3632)  cardinality_error_unscaled: 5.5000 (30.4562)  loss_ce_0_unscaled: 0.7291 (0.8293)  loss_bbox_0_unscaled: 0.0250 (0.0464)  loss_giou_0_unscaled: 0.3067 (0.3594)  cardinality_error_0_unscaled: 5.5000 (8.7183)  loss_ce_1_unscaled: 0.6829 (0.7433)  loss_bbox_1_unscaled: 0.0258 (0.0475)  loss_giou_1_unscaled: 0.3147 (0.3626)  cardinality_error_1_unscaled: 5.5000 (46.6548)  loss_ce_enc_unscaled: 0.7293 (0.8336)  loss_bbox_enc_unscaled: 0.0262 (0.0507)  loss_giou_enc_unscaled: 0.3349 (0.3800)  cardinality_error_enc_unscaled: 8.5000 (276.7017)  time: 1.6598  data: 0.0143  max mem: 12269
# Epoch: [0]  [ 340/1666]  eta: 0:36:59  lr: 0.000100  class_error: 0.00  loss: 6.4009 (7.0149)  loss_ce: 0.6612 (0.7270)  loss_bbox: 0.2006 (0.2399)  loss_giou: 0.6948 (0.7261)  loss_ce_0: 0.7012 (0.8263)  loss_bbox_0: 0.2006 (0.2317)  loss_giou_0: 0.7002 (0.7183)  loss_ce_1: 0.6729 (0.7418)  loss_bbox_1: 0.2089 (0.2372)  loss_giou_1: 0.6958 (0.7248)  loss_ce_enc: 0.6943 (0.8299)  loss_bbox_enc: 0.2079 (0.2528)  loss_giou_enc: 0.7200 (0.7591)  loss_ce_unscaled: 0.6612 (0.7270)  class_error_unscaled: 0.0000 (0.3175)  loss_bbox_unscaled: 0.0401 (0.0480)  loss_giou_unscaled: 0.3474 (0.3631)  cardinality_error_unscaled: 8.0000 (29.8424)  loss_ce_0_unscaled: 0.7012 (0.8263)  loss_bbox_0_unscaled: 0.0401 (0.0463)  loss_giou_0_unscaled: 0.3501 (0.3592)  cardinality_error_0_unscaled: 8.0000 (8.7441)  loss_ce_1_unscaled: 0.6729 (0.7418)  loss_bbox_1_unscaled: 0.0418 (0.0474)  loss_giou_1_unscaled: 0.3479 (0.3624)  cardinality_error_1_unscaled: 8.0000 (45.5674)  loss_ce_enc_unscaled: 0.6943 (0.8299)  loss_bbox_enc_unscaled: 0.0416 (0.0506)  loss_giou_enc_unscaled: 0.3600 (0.3795)  cardinality_error_enc_unscaled: 8.5000 (268.8798)  time: 1.6947  data: 0.0144  max mem: 12269
# Epoch: [0]  [ 350/1666]  eta: 0:36:47  lr: 0.000100  class_error: 0.00  loss: 6.4078 (6.9979)  loss_ce: 0.6909 (0.7269)  loss_bbox: 0.1941 (0.2384)  loss_giou: 0.6948 (0.7242)  loss_ce_0: 0.7311 (0.8248)  loss_bbox_0: 0.1940 (0.2302)  loss_giou_0: 0.6904 (0.7166)  loss_ce_1: 0.6918 (0.7415)  loss_bbox_1: 0.2010 (0.2355)  loss_giou_1: 0.6980 (0.7227)  loss_ce_enc: 0.7187 (0.8286)  loss_bbox_enc: 0.2130 (0.2510)  loss_giou_enc: 0.7200 (0.7574)  loss_ce_unscaled: 0.6909 (0.7269)  class_error_unscaled: 0.0000 (0.3085)  loss_bbox_unscaled: 0.0388 (0.0477)  loss_giou_unscaled: 0.3474 (0.3621)  cardinality_error_unscaled: 8.0000 (29.2386)  loss_ce_0_unscaled: 0.7311 (0.8248)  loss_bbox_0_unscaled: 0.0388 (0.0460)  loss_giou_0_unscaled: 0.3452 (0.3583)  cardinality_error_0_unscaled: 8.0000 (8.7422)  loss_ce_1_unscaled: 0.6918 (0.7415)  loss_bbox_1_unscaled: 0.0402 (0.0471)  loss_giou_1_unscaled: 0.3490 (0.3614)  cardinality_error_1_unscaled: 8.0000 (44.5157)  loss_ce_enc_unscaled: 0.7187 (0.8286)  loss_bbox_enc_unscaled: 0.0426 (0.0502)  loss_giou_enc_unscaled: 0.3600 (0.3787)  cardinality_error_enc_unscaled: 8.0000 (261.5605)  time: 1.7338  data: 0.0141  max mem: 12269
# Epoch: [0]  [ 360/1666]  eta: 0:36:27  lr: 0.000100  class_error: 0.00  loss: 6.4904 (6.9848)  loss_ce: 0.7168 (0.7269)  loss_bbox: 0.1651 (0.2369)  loss_giou: 0.6935 (0.7233)  loss_ce_0: 0.7493 (0.8234)  loss_bbox_0: 0.1568 (0.2289)  loss_giou_0: 0.6846 (0.7159)  loss_ce_1: 0.7249 (0.7413)  loss_bbox_1: 0.1639 (0.2341)  loss_giou_1: 0.6940 (0.7219)  loss_ce_enc: 0.7480 (0.8266)  loss_bbox_enc: 0.1783 (0.2492)  loss_giou_enc: 0.6864 (0.7564)  loss_ce_unscaled: 0.7168 (0.7269)  class_error_unscaled: 0.0000 (0.3000)  loss_bbox_unscaled: 0.0330 (0.0474)  loss_giou_unscaled: 0.3468 (0.3617)  cardinality_error_unscaled: 5.2500 (28.5990)  loss_ce_0_unscaled: 0.7493 (0.8234)  loss_bbox_0_unscaled: 0.0314 (0.0458)  loss_giou_0_unscaled: 0.3423 (0.3579)  cardinality_error_0_unscaled: 5.2500 (8.6717)  loss_ce_1_unscaled: 0.7249 (0.7413)  loss_bbox_1_unscaled: 0.0328 (0.0468)  loss_giou_1_unscaled: 0.3470 (0.3609)  cardinality_error_1_unscaled: 5.2500 (43.4536)  loss_ce_enc_unscaled: 0.7480 (0.8266)  loss_bbox_enc_unscaled: 0.0357 (0.0498)  loss_giou_enc_unscaled: 0.3432 (0.3782)  cardinality_error_enc_unscaled: 7.5000 (254.5325)  time: 1.6851  data: 0.0141  max mem: 12269
# Epoch: [0]  [ 370/1666]  eta: 0:36:13  lr: 0.000100  class_error: 0.00  loss: 6.3595 (6.9692)  loss_ce: 0.7168 (0.7277)  loss_bbox: 0.1478 (0.2352)  loss_giou: 0.6425 (0.7202)  loss_ce_0: 0.7735 (0.8230)  loss_bbox_0: 0.1496 (0.2276)  loss_giou_0: 0.6323 (0.7131)  loss_ce_1: 0.7263 (0.7422)  loss_bbox_1: 0.1485 (0.2326)  loss_giou_1: 0.6432 (0.7188)  loss_ce_enc: 0.7611 (0.8257)  loss_bbox_enc: 0.1876 (0.2486)  loss_giou_enc: 0.6580 (0.7547)  loss_ce_unscaled: 0.7168 (0.7277)  class_error_unscaled: 0.0000 (0.2919)  loss_bbox_unscaled: 0.0296 (0.0470)  loss_giou_unscaled: 0.3212 (0.3601)  cardinality_error_unscaled: 7.0000 (28.0842)  loss_ce_0_unscaled: 0.7735 (0.8230)  loss_bbox_0_unscaled: 0.0299 (0.0455)  loss_giou_0_unscaled: 0.3161 (0.3565)  cardinality_error_0_unscaled: 7.0000 (8.6947)  loss_ce_1_unscaled: 0.7263 (0.7422)  loss_bbox_1_unscaled: 0.0297 (0.0465)  loss_giou_1_unscaled: 0.3216 (0.3594)  cardinality_error_1_unscaled: 7.0000 (42.5377)  loss_ce_enc_unscaled: 0.7611 (0.8257)  loss_bbox_enc_unscaled: 0.0375 (0.0497)  loss_giou_enc_unscaled: 0.3290 (0.3773)  cardinality_error_enc_unscaled: 8.0000 (247.9124)  time: 1.6769  data: 0.0146  max mem: 12269
# ...
# Test:  [420/512]  eta: 0:00:30  class_error: 0.00  loss: 5.4083 (5.6511)  loss_ce: 0.6289 (0.6441)  loss_bbox: 0.1411 (0.1783)  loss_giou: 0.5216 (0.5541)  loss_ce_0: 0.6914 (0.6819)  loss_bbox_0: 0.1441 (0.1798)  loss_giou_0: 0.5409 (0.5577)  loss_ce_1: 0.6367 (0.6497)  loss_bbox_1: 0.1428 (0.1792)  loss_giou_1: 0.5303 (0.5556)  loss_ce_enc: 0.6836 (0.6909)  loss_bbox_enc: 0.1624 (0.1964)  loss_giou_enc: 0.5721 (0.5834)  loss_ce_unscaled: 0.6289 (0.6441)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0282 (0.0357)  loss_giou_unscaled: 0.2608 (0.2771)  cardinality_error_unscaled: 5.2500 (7.2933)  loss_ce_0_unscaled: 0.6914 (0.6819)  loss_bbox_0_unscaled: 0.0288 (0.0360)  loss_giou_0_unscaled: 0.2704 (0.2789)  cardinality_error_0_unscaled: 5.2500 (7.2933)  loss_ce_1_unscaled: 0.6367 (0.6497)  loss_bbox_1_unscaled: 0.0286 (0.0358)  loss_giou_1_unscaled: 0.2652 (0.2778)  cardinality_error_1_unscaled: 5.2500 (7.2933)  loss_ce_enc_unscaled: 0.6836 (0.6909)  loss_bbox_enc_unscaled: 0.0325 (0.0393)  loss_giou_enc_unscaled: 0.2861 (0.2917)  cardinality_error_enc_unscaled: 5.2500 (7.2933)  time: 0.3330  data: 0.0214  max mem: 12269
# Test:  [430/512]  eta: 0:00:27  class_error: 0.00  loss: 5.7708 (5.6547)  loss_ce: 0.6914 (0.6453)  loss_bbox: 0.1182 (0.1770)  loss_giou: 0.5874 (0.5552)  loss_ce_0: 0.7227 (0.6832)  loss_bbox_0: 0.1143 (0.1785)  loss_giou_0: 0.5966 (0.5588)  loss_ce_1: 0.6992 (0.6507)  loss_bbox_1: 0.1145 (0.1778)  loss_giou_1: 0.5826 (0.5568)  loss_ce_enc: 0.7109 (0.6913)  loss_bbox_enc: 0.1222 (0.1954)  loss_giou_enc: 0.6067 (0.5845)  loss_ce_unscaled: 0.6914 (0.6453)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0236 (0.0354)  loss_giou_unscaled: 0.2937 (0.2776)  cardinality_error_unscaled: 5.2500 (7.3068)  loss_ce_0_unscaled: 0.7227 (0.6832)  loss_bbox_0_unscaled: 0.0229 (0.0357)  loss_giou_0_unscaled: 0.2983 (0.2794)  cardinality_error_0_unscaled: 5.2500 (7.3068)  loss_ce_1_unscaled: 0.6992 (0.6507)  loss_bbox_1_unscaled: 0.0229 (0.0356)  loss_giou_1_unscaled: 0.2913 (0.2784)  cardinality_error_1_unscaled: 5.2500 (7.3068)  loss_ce_enc_unscaled: 0.7109 (0.6913)  loss_bbox_enc_unscaled: 0.0244 (0.0391)  loss_giou_enc_unscaled: 0.3033 (0.2922)  cardinality_error_enc_unscaled: 5.2500 (7.3068)  time: 0.3162  data: 0.0195  max mem: 12269
# Test:  [440/512]  eta: 0:00:24  class_error: 0.00  loss: 5.7386 (5.6520)  loss_ce: 0.6719 (0.6459)  loss_bbox: 0.1243 (0.1767)  loss_giou: 0.5426 (0.5543)  loss_ce_0: 0.7031 (0.6834)  loss_bbox_0: 0.1350 (0.1784)  loss_giou_0: 0.5432 (0.5580)  loss_ce_1: 0.6797 (0.6513)  loss_bbox_1: 0.1201 (0.1776)  loss_giou_1: 0.5523 (0.5559)  loss_ce_enc: 0.6875 (0.6916)  loss_bbox_enc: 0.1441 (0.1951)  loss_giou_enc: 0.5456 (0.5836)  loss_ce_unscaled: 0.6719 (0.6459)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0249 (0.0353)  loss_giou_unscaled: 0.2713 (0.2772)  cardinality_error_unscaled: 4.5000 (7.2642)  loss_ce_0_unscaled: 0.7031 (0.6834)  loss_bbox_0_unscaled: 0.0270 (0.0357)  loss_giou_0_unscaled: 0.2716 (0.2790)  cardinality_error_0_unscaled: 4.5000 (7.2642)  loss_ce_1_unscaled: 0.6797 (0.6513)  loss_bbox_1_unscaled: 0.0240 (0.0355)  loss_giou_1_unscaled: 0.2762 (0.2780)  cardinality_error_1_unscaled: 4.5000 (7.2642)  loss_ce_enc_unscaled: 0.6875 (0.6916)  loss_bbox_enc_unscaled: 0.0288 (0.0390)  loss_giou_enc_unscaled: 0.2728 (0.2918)  cardinality_error_enc_unscaled: 4.5000 (7.2642)  time: 0.3113  data: 0.0195  max mem: 12269
# Test:  [450/512]  eta: 0:00:20  class_error: 0.00  loss: 5.3801 (5.6484)  loss_ce: 0.6562 (0.6460)  loss_bbox: 0.1291 (0.1757)  loss_giou: 0.4643 (0.5547)  loss_ce_0: 0.6758 (0.6834)  loss_bbox_0: 0.1364 (0.1774)  loss_giou_0: 0.4670 (0.5580)  loss_ce_1: 0.6758 (0.6515)  loss_bbox_1: 0.1255 (0.1766)  loss_giou_1: 0.4676 (0.5564)  loss_ce_enc: 0.6797 (0.6913)  loss_bbox_enc: 0.1584 (0.1939)  loss_giou_enc: 0.4917 (0.5835)  loss_ce_unscaled: 0.6562 (0.6460)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0258 (0.0351)  loss_giou_unscaled: 0.2321 (0.2774)  cardinality_error_unscaled: 5.2500 (7.2306)  loss_ce_0_unscaled: 0.6758 (0.6834)  loss_bbox_0_unscaled: 0.0273 (0.0355)  loss_giou_0_unscaled: 0.2335 (0.2790)  cardinality_error_0_unscaled: 5.2500 (7.2306)  loss_ce_1_unscaled: 0.6758 (0.6515)  loss_bbox_1_unscaled: 0.0251 (0.0353)  loss_giou_1_unscaled: 0.2338 (0.2782)  cardinality_error_1_unscaled: 5.2500 (7.2306)  loss_ce_enc_unscaled: 0.6797 (0.6913)  loss_bbox_enc_unscaled: 0.0317 (0.0388)  loss_giou_enc_unscaled: 0.2459 (0.2918)  cardinality_error_enc_unscaled: 5.2500 (7.2306)  time: 0.3481  data: 0.0203  max mem: 12269
# Test:  [460/512]  eta: 0:00:17  class_error: 0.00  loss: 4.8664 (5.6350)  loss_ce: 0.6172 (0.6443)  loss_bbox: 0.1079 (0.1742)  loss_giou: 0.4767 (0.5544)  loss_ce_0: 0.6445 (0.6817)  loss_bbox_0: 0.1013 (0.1760)  loss_giou_0: 0.4670 (0.5577)  loss_ce_1: 0.6250 (0.6497)  loss_bbox_1: 0.1069 (0.1751)  loss_giou_1: 0.4868 (0.5561)  loss_ce_enc: 0.6719 (0.6896)  loss_bbox_enc: 0.1244 (0.1927)  loss_giou_enc: 0.5152 (0.5835)  loss_ce_unscaled: 0.6172 (0.6443)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0216 (0.0348)  loss_giou_unscaled: 0.2384 (0.2772)  cardinality_error_unscaled: 5.5000 (7.2082)  loss_ce_0_unscaled: 0.6445 (0.6817)  loss_bbox_0_unscaled: 0.0203 (0.0352)  loss_giou_0_unscaled: 0.2335 (0.2788)  cardinality_error_0_unscaled: 5.5000 (7.2082)  loss_ce_1_unscaled: 0.6250 (0.6497)  loss_bbox_1_unscaled: 0.0214 (0.0350)  loss_giou_1_unscaled: 0.2434 (0.2780)  cardinality_error_1_unscaled: 5.5000 (7.2082)  loss_ce_enc_unscaled: 0.6719 (0.6896)  loss_bbox_enc_unscaled: 0.0249 (0.0385)  loss_giou_enc_unscaled: 0.2576 (0.2917)  cardinality_error_enc_unscaled: 5.5000 (7.2082)  time: 0.3511  data: 0.0204  max mem: 12269
# Test:  [470/512]  eta: 0:00:14  class_error: 0.00  loss: 5.3832 (5.6318)  loss_ce: 0.6094 (0.6444)  loss_bbox: 0.1055 (0.1744)  loss_giou: 0.4506 (0.5533)  loss_ce_0: 0.6523 (0.6818)  loss_bbox_0: 0.1070 (0.1761)  loss_giou_0: 0.4665 (0.5567)  loss_ce_1: 0.6172 (0.6498)  loss_bbox_1: 0.1048 (0.1752)  loss_giou_1: 0.4499 (0.5549)  loss_ce_enc: 0.6758 (0.6898)  loss_bbox_enc: 0.1527 (0.1930)  loss_giou_enc: 0.4776 (0.5824)  loss_ce_unscaled: 0.6094 (0.6444)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0211 (0.0349)  loss_giou_unscaled: 0.2253 (0.2766)  cardinality_error_unscaled: 4.0000 (7.1401)  loss_ce_0_unscaled: 0.6523 (0.6818)  loss_bbox_0_unscaled: 0.0214 (0.0352)  loss_giou_0_unscaled: 0.2333 (0.2783)  cardinality_error_0_unscaled: 4.0000 (7.1401)  loss_ce_1_unscaled: 0.6172 (0.6498)  loss_bbox_1_unscaled: 0.0210 (0.0350)  loss_giou_1_unscaled: 0.2250 (0.2775)  cardinality_error_1_unscaled: 4.0000 (7.1401)  loss_ce_enc_unscaled: 0.6758 (0.6898)  loss_bbox_enc_unscaled: 0.0305 (0.0386)  loss_giou_enc_unscaled: 0.2388 (0.2912)  cardinality_error_enc_unscaled: 4.0000 (7.1401)  time: 0.3042  data: 0.0196  max mem: 12269
# Test:  [480/512]  eta: 0:00:10  class_error: 0.00  loss: 5.3832 (5.6300)  loss_ce: 0.6406 (0.6446)  loss_bbox: 0.1477 (0.1738)  loss_giou: 0.4743 (0.5535)  loss_ce_0: 0.6758 (0.6818)  loss_bbox_0: 0.1391 (0.1754)  loss_giou_0: 0.4945 (0.5568)  loss_ce_1: 0.6484 (0.6499)  loss_bbox_1: 0.1460 (0.1746)  loss_giou_1: 0.4818 (0.5551)  loss_ce_enc: 0.6836 (0.6897)  loss_bbox_enc: 0.1853 (0.1924)  loss_giou_enc: 0.4924 (0.5824)  loss_ce_unscaled: 0.6406 (0.6446)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0295 (0.0348)  loss_giou_unscaled: 0.2371 (0.2767)  cardinality_error_unscaled: 4.0000 (7.1289)  loss_ce_0_unscaled: 0.6758 (0.6818)  loss_bbox_0_unscaled: 0.0278 (0.0351)  loss_giou_0_unscaled: 0.2473 (0.2784)  cardinality_error_0_unscaled: 4.0000 (7.1289)  loss_ce_1_unscaled: 0.6484 (0.6499)  loss_bbox_1_unscaled: 0.0292 (0.0349)  loss_giou_1_unscaled: 0.2409 (0.2775)  cardinality_error_1_unscaled: 4.0000 (7.1289)  loss_ce_enc_unscaled: 0.6836 (0.6897)  loss_bbox_enc_unscaled: 0.0371 (0.0385)  loss_giou_enc_unscaled: 0.2462 (0.2912)  cardinality_error_enc_unscaled: 4.0000 (7.1289)  time: 0.3085  data: 0.0194  max mem: 12269
# Test:  [490/512]  eta: 0:00:07  class_error: 0.00  loss: 5.2373 (5.6351)  loss_ce: 0.6680 (0.6452)  loss_bbox: 0.1696 (0.1745)  loss_giou: 0.5390 (0.5531)  loss_ce_0: 0.6914 (0.6830)  loss_bbox_0: 0.1692 (0.1761)  loss_giou_0: 0.5132 (0.5563)  loss_ce_1: 0.6641 (0.6507)  loss_bbox_1: 0.1693 (0.1752)  loss_giou_1: 0.5234 (0.5546)  loss_ce_enc: 0.7031 (0.6910)  loss_bbox_enc: 0.1837 (0.1932)  loss_giou_enc: 0.5614 (0.5821)  loss_ce_unscaled: 0.6680 (0.6452)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0339 (0.0349)  loss_giou_unscaled: 0.2695 (0.2766)  cardinality_error_unscaled: 5.0000 (7.1008)  loss_ce_0_unscaled: 0.6914 (0.6830)  loss_bbox_0_unscaled: 0.0338 (0.0352)  loss_giou_0_unscaled: 0.2566 (0.2782)  cardinality_error_0_unscaled: 5.0000 (7.1008)  loss_ce_1_unscaled: 0.6641 (0.6507)  loss_bbox_1_unscaled: 0.0339 (0.0350)  loss_giou_1_unscaled: 0.2617 (0.2773)  cardinality_error_1_unscaled: 5.0000 (7.1008)  loss_ce_enc_unscaled: 0.7031 (0.6910)  loss_bbox_enc_unscaled: 0.0367 (0.0386)  loss_giou_enc_unscaled: 0.2807 (0.2911)  cardinality_error_enc_unscaled: 5.0000 (7.1008)  time: 0.3292  data: 0.0207  max mem: 12269
# Test:  [500/512]  eta: 0:00:03  class_error: 0.00  loss: 5.3022 (5.6356)  loss_ce: 0.6680 (0.6461)  loss_bbox: 0.1696 (0.1746)  loss_giou: 0.4758 (0.5531)  loss_ce_0: 0.6836 (0.6839)  loss_bbox_0: 0.1692 (0.1756)  loss_giou_0: 0.4774 (0.5560)  loss_ce_1: 0.6641 (0.6513)  loss_bbox_1: 0.1693 (0.1752)  loss_giou_1: 0.4622 (0.5545)  loss_ce_enc: 0.6914 (0.6913)  loss_bbox_enc: 0.1837 (0.1925)  loss_giou_enc: 0.5453 (0.5816)  loss_ce_unscaled: 0.6680 (0.6461)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0339 (0.0349)  loss_giou_unscaled: 0.2379 (0.2765)  cardinality_error_unscaled: 4.0000 (7.0544)  loss_ce_0_unscaled: 0.6836 (0.6839)  loss_bbox_0_unscaled: 0.0338 (0.0351)  loss_giou_0_unscaled: 0.2387 (0.2780)  cardinality_error_0_unscaled: 4.0000 (7.0544)  loss_ce_1_unscaled: 0.6641 (0.6513)  loss_bbox_1_unscaled: 0.0339 (0.0350)  loss_giou_1_unscaled: 0.2311 (0.2773)  cardinality_error_1_unscaled: 4.0000 (7.0544)  loss_ce_enc_unscaled: 0.6914 (0.6913)  loss_bbox_enc_unscaled: 0.0367 (0.0385)  loss_giou_enc_unscaled: 0.2726 (0.2908)  cardinality_error_enc_unscaled: 4.0000 (7.0544)  time: 0.3194  data: 0.0206  max mem: 12269
# Test:  [510/512]  eta: 0:00:00  class_error: 0.00  loss: 5.3022 (5.6225)  loss_ce: 0.6562 (0.6458)  loss_bbox: 0.1183 (0.1732)  loss_giou: 0.4758 (0.5511)  loss_ce_0: 0.6758 (0.6835)  loss_bbox_0: 0.1227 (0.1744)  loss_giou_0: 0.4774 (0.5542)  loss_ce_1: 0.6602 (0.6507)  loss_bbox_1: 0.1164 (0.1740)  loss_giou_1: 0.4622 (0.5527)  loss_ce_enc: 0.6719 (0.6909)  loss_bbox_enc: 0.1447 (0.1918)  loss_giou_enc: 0.4784 (0.5803)  loss_ce_unscaled: 0.6562 (0.6458)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0237 (0.0346)  loss_giou_unscaled: 0.2379 (0.2756)  cardinality_error_unscaled: 4.5000 (7.0196)  loss_ce_0_unscaled: 0.6758 (0.6835)  loss_bbox_0_unscaled: 0.0245 (0.0349)  loss_giou_0_unscaled: 0.2387 (0.2771)  cardinality_error_0_unscaled: 4.5000 (7.0196)  loss_ce_1_unscaled: 0.6602 (0.6507)  loss_bbox_1_unscaled: 0.0233 (0.0348)  loss_giou_1_unscaled: 0.2311 (0.2763)  cardinality_error_1_unscaled: 4.5000 (7.0196)  loss_ce_enc_unscaled: 0.6719 (0.6909)  loss_bbox_enc_unscaled: 0.0289 (0.0384)  loss_giou_enc_unscaled: 0.2392 (0.2901)  cardinality_error_enc_unscaled: 4.5000 (7.0196)  time: 0.3009  data: 0.0191  max mem: 12269
# Test:  [511/512]  eta: 0:00:00  class_error: 0.00  loss: 5.0879 (5.6183)  loss_ce: 0.6406 (0.6452)  loss_bbox: 0.1183 (0.1733)  loss_giou: 0.4737 (0.5505)  loss_ce_0: 0.6445 (0.6829)  loss_bbox_0: 0.1227 (0.1745)  loss_giou_0: 0.4458 (0.5536)  loss_ce_1: 0.6523 (0.6502)  loss_bbox_1: 0.1164 (0.1741)  loss_giou_1: 0.4520 (0.5521)  loss_ce_enc: 0.6641 (0.6905)  loss_bbox_enc: 0.1447 (0.1917)  loss_giou_enc: 0.4747 (0.5795)  loss_ce_unscaled: 0.6406 (0.6452)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0237 (0.0347)  loss_giou_unscaled: 0.2368 (0.2753)  cardinality_error_unscaled: 4.0000 (7.0078)  loss_ce_0_unscaled: 0.6445 (0.6829)  loss_bbox_0_unscaled: 0.0245 (0.0349)  loss_giou_0_unscaled: 0.2229 (0.2768)  cardinality_error_0_unscaled: 4.0000 (7.0078)  loss_ce_1_unscaled: 0.6523 (0.6502)  loss_bbox_1_unscaled: 0.0233 (0.0348)  loss_giou_1_unscaled: 0.2260 (0.2761)  cardinality_error_1_unscaled: 4.0000 (7.0078)  loss_ce_enc_unscaled: 0.6641 (0.6905)  loss_bbox_enc_unscaled: 0.0289 (0.0383)  loss_giou_enc_unscaled: 0.2374 (0.2898)  cardinality_error_enc_unscaled: 4.0000 (7.0078)  time: 0.2895  data: 0.0185  max mem: 12269
# Test: Total time: 0:02:50 (0.3322 s / it)
# Averaged stats: class_error: 0.00  loss: 5.0879 (5.6183)  loss_ce: 0.6406 (0.6452)  loss_bbox: 0.1183 (0.1733)  loss_giou: 0.4737 (0.5505)  loss_ce_0: 0.6445 (0.6829)  loss_bbox_0: 0.1227 (0.1745)  loss_giou_0: 0.4458 (0.5536)  loss_ce_1: 0.6523 (0.6502)  loss_bbox_1: 0.1164 (0.1741)  loss_giou_1: 0.4520 (0.5521)  loss_ce_enc: 0.6641 (0.6905)  loss_bbox_enc: 0.1447 (0.1917)  loss_giou_enc: 0.4747 (0.5795)  loss_ce_unscaled: 0.6406 (0.6452)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0237 (0.0347)  loss_giou_unscaled: 0.2368 (0.2753)  cardinality_error_unscaled: 4.0000 (7.0078)  loss_ce_0_unscaled: 0.6445 (0.6829)  loss_bbox_0_unscaled: 0.0245 (0.0349)  loss_giou_0_unscaled: 0.2229 (0.2768)  cardinality_error_0_unscaled: 4.0000 (7.0078)  loss_ce_1_unscaled: 0.6523 (0.6502)  loss_bbox_1_unscaled: 0.0233 (0.0348)  loss_giou_1_unscaled: 0.2260 (0.2761)  cardinality_error_1_unscaled: 4.0000 (7.0078)  loss_ce_enc_unscaled: 0.6641 (0.6905)  loss_bbox_enc_unscaled: 0.0289 (0.0383)  loss_giou_enc_unscaled: 0.2374 (0.2898)  cardinality_error_enc_unscaled: 4.0000 (7.0078)
# Accumulating evaluation results...
# DONE (t=1.57s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.774
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.355
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.308
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.448
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.506
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.430
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.541
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.708
# Training time 0:52:08
# Results saved to output/results.json
# Results saved to output/metrics_plot.png

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(history)

plt.figure(figsize=(12, 8))

plt.plot(
    df['epoch'],
    df['train_loss'],
    label='Training Loss',
    marker='o',
    linestyle='-'
)

plt.plot(
    df['epoch'],
    df['test_loss'],
    label='Validation Loss',
    marker='o',
    linestyle='--'
)

plt.title('Train/Validation Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(history)

df['avg_precision'] = df['test_coco_eval_bbox'].apply(lambda arr: arr[0])
df['avg_recall'] = df['test_coco_eval_bbox'].apply(lambda arr: arr[6])

plt.figure(figsize=(12, 8))
plt.plot(
    df['epoch'],
    df['avg_precision'],
    marker='o',
    linestyle='-'
)
plt.title('AP (IoU=0.50:0.95, area=all, maxDets=100) over Epochs')
plt.xlabel('Epoch')
plt.ylabel('AP')
plt.grid(True)
plt.show()


plt.figure(figsize=(12, 8))
plt.plot(
    df['epoch'],
    df['avg_recall'],
    marker='o',
    linestyle='-'
)
plt.title('AR (IoU=0.50:0.95, area=all, maxDets=1) over Epochs')
plt.xlabel('Epoch')
plt.ylabel('AR')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Run inference with fine-tuned model

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(thickness=thickness)
label_annotator = sv.LabelAnnotator(
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    text_thickness=thickness,
    smart_position=True)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %%
import supervision as sv
from rfdetr import RFDETRBase
from PIL import Image

detections_images = []

for i in range(16):
    path, image, annotations = ds[i]
    image = Image.open(path)

    detections = model.predict(image, threshold=0.5)

    text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
    thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

    bbox_annotator = sv.BoxAnnotator(thickness=thickness)
    label_annotator = sv.LabelAnnotator(
        text_color=sv.Color.BLACK,
        text_scale=text_scale,
        text_thickness=thickness,
        smart_position=True)

    detections_labels = [
        f"{ds.classes[class_id]} {confidence:.2f}"
        for class_id, confidence
        in zip(detections.class_id, detections.confidence)
    ]

    detections_image = image.copy()
    detections_image = bbox_annotator.annotate(detections_image, detections)
    detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

    detections_images.append(detections_image)

sv.plot_images_grid(images=detections_images, grid_size=(4, 4))

# %% [markdown]
# ## Evaluate fine-tuned model

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0.5)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 1182/1182 [00:58<00:00, 20.13it/s]

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()

map_result.plot()

# %%
confusion_matrix = sv.ConfusionMatrix.from_detections(
    predictions=predictions,
    targets=targets,
    classes=ds.classes
)

_ = confusion_matrix.plot()
